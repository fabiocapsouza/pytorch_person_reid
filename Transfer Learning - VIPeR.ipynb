# %% [markdown]
# # Transfer Learning para o dataset VIPeR
#
# Modelo treinado com os datasets Market-1501 e CUHK03

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
import torch
import torch as tc
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import transforms
from torchvision import datasets as tv_datasets
from torch.autograd import Variable
from  torch.utils.data import DataLoader
import torch.optim.lr_scheduler as lr_scheduler
import matplotlib.pyplot as plt
# %matplotlib inline
import torchvision.datasets as dset
import numpy as np
import cv2

from center_loss import CenterLoss
from frw import L2_penalty_with_constant
from reid_model import ReID_Net
from datasets import VIPeR
from custom_transforms import RandomTranslation
from evaluation import pairwise_squared_euclidian_distance, generate_query, \
                        get_topk_results, mapk, calculate_mAP
import time
import shutil

# %% [markdown]
# ## Dataset, transformações de data augmentation e DataLoaders

# %%
data_transforms = {
    'train': transforms.Compose([
        RandomTranslation(0.1),   # translação em numpy array
        transforms.ToPILImage(),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),    # range [0.0, 1.0]
        transforms.Lambda(lambda t: t/0.5 - 1)    # range [-1.0, 1.0]
    ]),
    'valid': transforms.Compose([
        transforms.ToTensor(),
        transforms.Lambda(lambda t: t/0.5 - 1)
    ])
}

# %%
datasets = {
    'train': VIPeR('../reid/datasets/viper_train_correct.npz', 
                            transform=data_transforms['train']),
    'valid': VIPeR('../reid/datasets/viper_train_correct.npz', train=False, transform=data_transforms['valid'])
}

batch_size = 128
dset_loaders = {
    'train': DataLoader(datasets['train'], batch_size=batch_size, shuffle=True, num_workers=4),
    'valid': DataLoader(datasets['valid'], batch_size=batch_size, shuffle=False, num_workers=4)
}

# %%
print('VIPeR:')
print('Treinamento:')
print('X:', datasets['train'].X.shape, datasets['train'].X.dtype, datasets['train'].X.min(), datasets['train'].X.max())
print('y:', datasets['train'].y.shape, datasets['train'].y.dtype, datasets['train'].y.min(), datasets['train'].y.max())
print('Validação:')
print('X:', datasets['valid'].X.shape, datasets['valid'].X.dtype, datasets['valid'].X.min(), datasets['valid'].X.max())
print('y:', datasets['valid'].y.shape, datasets['valid'].y.dtype, datasets['valid'].y.min(), datasets['valid'].y.max())
# Out:
# VIPeR:
# Treinamento:
# X: (432, 128, 48, 3) uint8 0 255
# y: (432,) int64 0 215
# Validação:
# X: (200, 128, 48, 3) uint8 0 255
# y: (200,) int64 0 99

# %%
print(len(dset_loaders['train']), len(dset_loaders['valid']))
# Out:
# 4 2

# %% [markdown]
# # Carregando o modelo para Transfer Learning

# %% [markdown]
# O modelo carregado tem a última camada `classifier` e o buffer `centers` com dimensões incorretas para o uso no treinamento do VIPeR.

# %%
model_to_transfer = 'market1501_and_cuhk03_map_epoch_136.pth'
ckpt = torch.load(model_to_transfer)

# %%
num_centers = ckpt['state_dict']['centers'].size(0)
print(num_centers)
# Out:
# 1918

# %%
num_classes = len(np.unique(datasets['train'].y))
print('Novo número de classes: ', num_classes)
# Out:
# Novo número de classes:  216

# %%
model = ReID_Net(num_centers)
model.load_state_dict(ckpt['state_dict'])
model.prepare_model_to_transfer(num_classes)

# %%
print('Novas dimensões dos centros: {}'.format(model.centers.size()))
print('Nova camada final: ', model.classifier)

## Dataset, transformações de data augmentation e DataLoaders
# Out:
# Novas dimensões dos centros: torch.Size([216, 512])
# Nova camada final:  Linear (512 -> 216)

# %% [markdown]
# ## Funções auxiliares

# %%
class MetricAverager(object):
    
    def __init__(self):
        self._n = 0
        self._mean = 0
        self._min = np.Inf
        
    def update(self, val):
        self._n += 1
        self._mean = (self._mean*(self._n - 1) + val) / self._n
        if val < self._min:
            self._min = val

    def clear(self):
        self._n = 0
        self._mean = 0
        self._min = np.Inf

    @property
    def mean(self):
        return self._mean

    @property
    def min(self):
        return self._min

    def __str__ (self):
        return 'MetricAverager(Mean: {:.5f}, n: {})'.format(self._mean, self._n)
        
    def __format__(self, format_spec):
        return format(self._mean, format_spec)

# %%
def save_checkpoint(state, is_best, filename='checkpoint.pth'):
    torch.save(state, filename)
    if is_best:
        import os.path as osp
        fname, ext = osp.splitext(filename)
        best_filename = '{}_best{}'.format(*osp.splitext(filename))
        shutil.copyfile(filename, best_filename)

# %%
def load_checkpoint(filename, model, optimizer):
    print('Carregando modelo {}'.format(filename))
    checkpoint = torch.load(filename)
    model.load_state_dict(checkpoint['state_dict'])
    scheduler = checkpoint.get('scheduler', None)
    epoch = checkpoint['epoch']
    best_val_loss = checkpoint['best_val_loss']
    train_history = checkpoint.get('history', [])
    
    print('Carregado.')
    return scheduler, epoch, best_val_loss, train_history

# %%
def train_epoch(model, optimizer, epoch, criterions, train_loader, val_loader, use_cuda,
                lambda_cl, beta_frw, query_splits, cuda_device=None):
    print("Training... Epoch = %d" % epoch)

    train_accum = 0
    n_train_samples = 0
    val_accum = 0
    n_val_samples = 0
    
    tlosses = {
        'center_loss': MetricAverager(),
        'softmax_loss': MetricAverager(),
        'total': MetricAverager(),
    }
    
    #train
    model.train(True)
    t0 = time.time()
    for i,(data, target) in enumerate(train_loader):
        
        if use_cuda:
            data = data.cuda()
            target = target.cuda()
        data, target = Variable(data), Variable(target)
        
        features, pred = model(data)
        
        # Softmax loss + center loss
        softmax_loss = criterions[0](pred, target)
        center_loss = lambda_cl * criterions[1](features, target)
        loss = softmax_loss + center_loss
        
        # Acrescenta a penalização L2 na camada FRW
        for (name, p) in model.named_parameters():
            if name == 'frw.weight' or name == 'fc_embeddings.3.weight':
                loss += beta_frw * criterions[2](p)
        
        _, preds = torch.max(pred.data, 1)
        correct = (preds == target.data).sum()
        train_accum += correct
        n_train_samples += target.size(0)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        tlosses['center_loss'].update(center_loss.data.cpu().numpy()[0])
        tlosses['softmax_loss'].update(softmax_loss.data.cpu().numpy()[0])
        tlosses['total'].update(loss.data.cpu().numpy()[0])
        
        t1 = time.time() - t0
        train_string = 'Epoch {}, Batch {}/{} ({:.1f}s): Center loss {:.4f}, Softmax loss {:.4f}, ' \
            'total {:.4f}'.format(epoch, i+1, len(train_loader), t1, tlosses['center_loss'], 
                                  tlosses['softmax_loss'], tlosses['total'])
        print(train_string, end='\r' if i < len(train_loader)-1 else '\n')
    
    train_acc = train_accum / n_train_samples
    print('Train accuracy: {:.2%}'.format(train_acc))
        
    # Validation: in the validation phase, we extract the features of all the validation images.
    # Then, we calculate the pairwise euclidian distance for all samples and calculate
    # the Mean Average Precision for the rankings in a Cross-camera search configuration: the query and
    # gallery sets have images from different camera views and, for each person identity, one image 
    # is randomly selected for each set. This is done for N query/gallery split configurations.
    
    t0 = time.time()
    model.train(False)
    
    val_feats = []
    val_pids = []
    
    valid_metrics = {
        'map': MetricAverager(),
    }
    
    for i, (data, target) in enumerate(val_loader):
        
        if use_cuda:
            data = data.cuda()
        data = Variable(data, volatile=True)

        features, pred = model(data)
        val_feats.append(features.data.cpu())
        
    val_feats = torch.cat(val_feats)
    
    # Calculates mAP for the validation set, as if it was a Query-Gallery set
    val_dataset = val_loader.dataset
    val_cam_ids = val_dataset.cam_ids
    y_val = val_dataset.y
    
    # Gallery: may or may not include distractors
    y_gallery = y_val
    gal_cam_ids = val_cam_ids
    
    for i, query_indices_by_cam in enumerate(query_splits):
        #query_indices_by_cam = generate_query(y_val, val_cam_ids)
        val_map = calculate_mAP(query_indices_by_cam, val_feats, y_gallery, gal_cam_ids)
        valid_metrics['map'].update(val_map)

        t1 = time.time() - t0
        print('Validation mAP (split {:>2}/{}) ({:.1f}s): {:.2%}'.format(i+1, len(query_splits),
                t1, valid_metrics['map'].mean), end='\r' if i+1 < len(query_splits) else '\n')
        
    print('-'*80)
        
    
    metrics = {
        'train': {
            'losses': {
                'center_loss': tlosses['center_loss'].mean,
                'softmax_loss': tlosses['softmax_loss'].mean,
                'total': tlosses['total'].mean,
            },
            'accuracy': train_acc,
        },
        'valid': {
            'map': valid_metrics['map'].mean
        }
    }
    
    return metrics

# %% [markdown]
# # Loop de treinamento

# %%
def train(epochs, model=None, resume=None, checkpoint_fn=None, **train_args):
    best_val_loss = None
    last_epoch = 0
    
    train_history = []
    
    use_cuda = train_args.get('use_cuda')
    num_classes = train_args.pop('num_classes', None)
    
    if model is None:
        if num_classes is None:
            raise ValueError('Deve-se informar o número de classes {`num_classes`}')
        model = ReID_Net(num_classes)
    
    if resume is not None:
        scheduler, last_epoch, best_val_loss, train_history = load_checkpoint(resume, model, optimizer4nn)
        num_classes = model.centers.size(0)
    
    # NLLLoss
    nllloss = nn.NLLLoss() #CrossEntropyLoss = log_softmax + NLLLoss
    # CenterLoss
    loss_weight = 1.0

    # FRW L2 penalty
    frw_l2_penalty = L2_penalty_with_constant(200)
    
    if use_cuda:
        nllloss = nllloss.cuda()
        model = model.cuda()
        frw_l2_penalty = frw_l2_penalty.cuda()
        
    
    alpha = train_args.pop('alpha')

    centerloss = CenterLoss(model, model.centers, num_classes, alpha)
    criterions = [nllloss, centerloss, frw_l2_penalty]

    # optimzer4nn
    lr = train_args.pop('lr')
    weight_decay = train_args.pop('weight_decay')
    optimizer4nn = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), 
                                     lr=lr, weight_decay=weight_decay)
    
    # LR Scheduler
    scheduler_patience = train_args.pop('scheduler_patience', 35)
    scheduler_factor = train_args.pop('scheduler_factor', 0.1)
    scheduler = lr_scheduler.ReduceLROnPlateau(optimizer4nn, mode='max',
                                               patience=scheduler_patience, 
                                               factor=scheduler_factor, verbose=True)
        
    max_val_map = best_val_loss or -np.Inf
    
    patience = train_args.pop('patience', 50)
    no_improve = 0
    
    print('train_args:', train_args, '\n')
    
    # Gera os splits de query e gallery que serão usados nas métricas de validação
    val_dataset = train_args['val_loader'].dataset
    query_splits = []
    for i in range(5):
        query_splits.append(generate_query(val_dataset.y, val_dataset.cam_ids))
    
    for epoch in range(last_epoch+1, epochs):

        metrics = train_epoch(model, optimizer4nn, epoch, criterions,
                              query_splits=query_splits, **train_args)
        
        scheduler.step(metrics['valid']['map'])
        train_history.append(metrics)
        
        # Save checkpoint and EarlyStop
        if metrics['valid']['map'] > max_val_map:
            print("Max. Valid. mAP / Epoch's Valid. mAP: {:.2%} | {:.2%}".format(
                max_val_map, metrics['valid']['map']))
            print('Salvando melhor modelo...')
            max_val_map = metrics['valid']['map']
            state = {
                'epoch': epoch,
                'state_dict': model.state_dict(),
                'best_val_loss': max_val_map,
                'train_softmax_loss': metrics['train']['losses']['softmax_loss'],
                'history': train_history,
            }
            opts = {'is_best': False}
            if checkpoint_fn is not None:
                opts.update({'filename': checkpoint_fn.format(epoch+1)})
            save_checkpoint(state, **opts)
            no_improve = 0
            print('-'*80)
        else:
            no_improve += 1
            if no_improve > patience:
                print('Early stopping at epoch {}.'.format(epoch))
                break
                
    return model, train_history

# %% [markdown]
# # Primeira etapa: treinamento somente da última camada
#
# Congela todos os parâmetros, exceto os da última camada

# %%
# len(model.parameters) == 53
for i, p in enumerate(model.parameters()):
    if i not in (51, 52):
        p.requires_grad = False

# Verifica que há apenas 2 parâmetros com requires_grad == True
for p in filter(lambda x: x.requires_grad, model.parameters()):
    print(p.size())
# Out:
# torch.Size([216, 512])
# torch.Size([216])

# %% [markdown]
# ### Parâmetros de treinamento

# %%
epochs = 500

train_params = {
    'lr': 0.0001,
    'weight_decay': 0.001,
    'lambda_cl': 0.01,
    'alpha': 0.5,
    'num_classes': len(np.unique(datasets['train'].y)),
    'train_loader': dset_loaders['train'],
    'val_loader': dset_loaders['valid'],
    'use_cuda': True,
    'beta_frw': 0.0001,
    'cuda_device': None,
    'patience': 50,
    'scheduler_patience': 20,
    'scheduler_factor': 0.1
}

# %%
try:
    model, train_history = train(epochs, model=model, 
                                 checkpoint_fn='transfer_viper_classifier_{}.pth', 
                                 **train_params)
    
except KeyboardInterrupt:
    print('Interrompendo...')
# Out:
# train_args: {'use_cuda': True, 'train_loader': <torch.utils.data.dataloader.DataLoader object at 0x7fd826cd2d68>, 'val_loader': <torch.utils.data.dataloader.DataLoader object at 0x7fd826cd24a8>, 'lambda_cl': 0.01, 'cuda_device': None, 'beta_frw': 0.0001}
#
# Training... Epoch = 1
# Epoch 1, Batch 4/4 (0.3s): Center loss 4.2064, Softmax loss 5.5125, total 9.72135
# Train accuracy: 0.69%
# Validation mAP (split  5/5) (0.3s): 40.72%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: -inf% | 40.72%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 2
# Epoch 2, Batch 4/4 (0.4s): Center loss 2.0806, Softmax loss 5.4690, total 7.5520
# Train accuracy: 1.16%
# Validation mAP (split  5/5) (0.2s): 40.52%
# --------------------------------------------------------------------------------
# Training... Epoch = 3
# Epoch 3, Batch 4/4 (0.4s): Center loss 1.3672, Softmax loss 5.4062, total 6.7758
# Train accuracy: 0.46%
# Validation mAP (split  5/5) (0.3s): 41.03%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 40.72% | 41.03%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 4
# Epoch 4, Batch 4/4 (0.5s): Center loss 1.0730, Softmax loss 5.3699, total 6.4454
# Train accuracy: 1.39%
# Validation mAP (split  5/5) (0.3s): 42.14%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 41.03% | 42.14%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 5
# Epoch 5, Batch 4/4 (0.5s): Center loss 0.9866, Softmax loss 5.3461, total 6.3351
# Train accuracy: 0.69%
# Validation mAP (split  5/5) (0.2s): 41.96%
# --------------------------------------------------------------------------------
# Training... Epoch = 6
# Epoch 6, Batch 4/4 (0.4s): Center loss 0.9761, Softmax loss 5.3192, total 6.2977
# Train accuracy: 1.39%
# Validation mAP (split  5/5) (0.3s): 42.18%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 42.14% | 42.18%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 7
# Epoch 7, Batch 4/4 (0.4s): Center loss 0.9412, Softmax loss 5.2651, total 6.2087
# Train accuracy: 1.39%
# Validation mAP (split  5/5) (0.3s): 42.00%
# --------------------------------------------------------------------------------
# Training... Epoch = 8
# Epoch 8, Batch 4/4 (0.3s): Center loss 0.9501, Softmax loss 5.2214, total 6.1740
# Train accuracy: 1.62%
# Validation mAP (split  5/5) (0.3s): 42.16%
# --------------------------------------------------------------------------------
# Training... Epoch = 9
# Epoch 9, Batch 4/4 (0.4s): Center loss 0.9451, Softmax loss 5.1835, total 6.1311
# Train accuracy: 1.85%
# Validation mAP (split  5/5) (0.2s): 42.64%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 42.18% | 42.64%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 10
# Epoch 10, Batch 4/4 (0.4s): Center loss 0.9402, Softmax loss 5.1371, total 6.0797
# Train accuracy: 2.31%
# Validation mAP (split  5/5) (0.3s): 42.26%
# --------------------------------------------------------------------------------
# Training... Epoch = 11
# Epoch 11, Batch 4/4 (0.4s): Center loss 0.9551, Softmax loss 5.0945, total 6.0520
# Train accuracy: 2.78%
# Validation mAP (split  5/5) (0.2s): 41.96%
# --------------------------------------------------------------------------------
# Training... Epoch = 12
# Epoch 12, Batch 4/4 (0.4s): Center loss 0.9506, Softmax loss 5.0878, total 6.0408
# Train accuracy: 3.47%
# Validation mAP (split  5/5) (0.2s): 42.08%
# --------------------------------------------------------------------------------
# Training... Epoch = 13
# Epoch 13, Batch 4/4 (0.4s): Center loss 0.9723, Softmax loss 5.0582, total 6.0329
# Train accuracy: 2.78%
# Validation mAP (split  5/5) (0.3s): 42.34%
# --------------------------------------------------------------------------------
# Training... Epoch = 14
# Epoch 14, Batch 4/4 (0.4s): Center loss 0.9508, Softmax loss 4.9736, total 5.9268
# Train accuracy: 4.40%
# Validation mAP (split  5/5) (0.3s): 41.48%
# --------------------------------------------------------------------------------
# Training... Epoch = 15
# Epoch 15, Batch 4/4 (0.4s): Center loss 0.9485, Softmax loss 4.9564, total 5.9073
# Train accuracy: 4.63%
# Validation mAP (split  5/5) (0.2s): 41.80%
# --------------------------------------------------------------------------------
# Training... Epoch = 16
# Epoch 16, Batch 4/4 (0.3s): Center loss 0.9513, Softmax loss 4.9212, total 5.8750
# Train accuracy: 5.32%
# Validation mAP (split  5/5) (0.2s): 42.12%
# --------------------------------------------------------------------------------
# Training... Epoch = 17
# Epoch 17, Batch 4/4 (0.5s): Center loss 0.9448, Softmax loss 4.8820, total 5.8293
# Train accuracy: 4.86%
# Validation mAP (split  5/5) (0.2s): 41.83%
# --------------------------------------------------------------------------------
# Training... Epoch = 18
# Epoch 18, Batch 4/4 (0.3s): Center loss 0.9501, Softmax loss 4.8612, total 5.8137
# Train accuracy: 8.33%
# Validation mAP (split  5/5) (0.2s): 41.56%
# --------------------------------------------------------------------------------
# Training... Epoch = 19
# Epoch 19, Batch 4/4 (0.4s): Center loss 0.9578, Softmax loss 4.8322, total 5.7924
# Train accuracy: 8.10%
# Validation mAP (split  5/5) (0.3s): 41.54%
# --------------------------------------------------------------------------------
# Training... Epoch = 20
# Epoch 20, Batch 4/4 (0.5s): Center loss 0.9522, Softmax loss 4.7790, total 5.7336
# Train accuracy: 8.56%
# Validation mAP (split  5/5) (0.3s): 41.60%
# --------------------------------------------------------------------------------
# Training... Epoch = 21
# Epoch 21, Batch 4/4 (0.4s): Center loss 0.9439, Softmax loss 4.7608, total 5.7071
# Train accuracy: 10.65%
# Validation mAP (split  5/5) (0.3s): 41.29%
# --------------------------------------------------------------------------------
# Training... Epoch = 22
# Epoch 22, Batch 4/4 (0.4s): Center loss 0.9400, Softmax loss 4.7204, total 5.6628
# Train accuracy: 10.19%
# Validation mAP (split  5/5) (0.2s): 41.54%
# --------------------------------------------------------------------------------
# Training... Epoch = 23
# Epoch 23, Batch 4/4 (0.4s): Center loss 0.9716, Softmax loss 4.6534, total 5.6274
# Train accuracy: 11.11%
# Validation mAP (split  5/5) (0.3s): 41.35%
# --------------------------------------------------------------------------------
# Training... Epoch = 24
# Epoch 24, Batch 4/4 (0.3s): Center loss 0.9365, Softmax loss 4.6513, total 5.5902
# Train accuracy: 14.81%
# Validation mAP (split  5/5) (0.3s): 42.00%
# --------------------------------------------------------------------------------
# Training... Epoch = 25
# Epoch 25, Batch 4/4 (0.4s): Center loss 0.9420, Softmax loss 4.5985, total 5.5429
# Train accuracy: 14.58%
# Validation mAP (split  5/5) (0.3s): 41.70%
# --------------------------------------------------------------------------------
# Training... Epoch = 26
# Epoch 26, Batch 4/4 (0.3s): Center loss 0.9340, Softmax loss 4.5668, total 5.5032
# Train accuracy: 15.51%
# Validation mAP (split  5/5) (0.3s): 42.02%
# --------------------------------------------------------------------------------
# Training... Epoch = 27
# Epoch 27, Batch 4/4 (0.4s): Center loss 0.9688, Softmax loss 4.5508, total 5.5220
# Train accuracy: 13.89%
# Validation mAP (split  5/5) (0.2s): 42.04%
# --------------------------------------------------------------------------------
# Training... Epoch = 28
# Epoch 28, Batch 4/4 (0.4s): Center loss 0.9605, Softmax loss 4.5101, total 5.4730
# Train accuracy: 15.97%
# Validation mAP (split  5/5) (0.2s): 41.76%
# --------------------------------------------------------------------------------
# Training... Epoch = 29
# Epoch 29, Batch 4/4 (0.4s): Center loss 0.9442, Softmax loss 4.4993, total 5.4459
# Train accuracy: 18.29%
# Validation mAP (split  5/5) (0.3s): 41.36%
# --------------------------------------------------------------------------------
# Training... Epoch = 30
# Epoch 30, Batch 4/4 (0.4s): Center loss 0.9475, Softmax loss 4.4493, total 5.3993
# Train accuracy: 18.75%
# Validation mAP (split  5/5) (0.4s): 41.96%
# --------------------------------------------------------------------------------
# Epoch    29: reducing learning rate of group 0 to 1.0000e-05.
# Training... Epoch = 31
# Epoch 31, Batch 4/4 (0.5s): Center loss 0.9420, Softmax loss 4.4278, total 5.3722
# Train accuracy: 19.68%
# Validation mAP (split  5/5) (0.4s): 41.71%
# --------------------------------------------------------------------------------
# Training... Epoch = 32
# Epoch 32, Batch 4/4 (0.4s): Center loss 0.9626, Softmax loss 4.4327, total 5.3978
# Train accuracy: 18.29%
# Validation mAP (split  5/5) (0.2s): 41.52%
# --------------------------------------------------------------------------------
# Training... Epoch = 33
# Epoch 33, Batch 4/4 (0.3s): Center loss 0.9553, Softmax loss 4.4064, total 5.3642
# Train accuracy: 21.99%
# Validation mAP (split  5/5) (0.3s): 41.48%
# --------------------------------------------------------------------------------
# Training... Epoch = 34
# Epoch 34, Batch 4/4 (0.4s): Center loss 0.9227, Softmax loss 4.4122, total 5.3373
# Train accuracy: 20.60%
# Validation mAP (split  5/5) (0.3s): 41.38%
# --------------------------------------------------------------------------------
# Training... Epoch = 35
# Epoch 35, Batch 4/4 (0.4s): Center loss 0.9386, Softmax loss 4.4217, total 5.3627
# Train accuracy: 18.98%
# Validation mAP (split  5/5) (0.3s): 41.87%
# --------------------------------------------------------------------------------
# Training... Epoch = 36
# Epoch 36, Batch 4/4 (0.4s): Center loss 0.9320, Softmax loss 4.4273, total 5.3618
# Train accuracy: 18.98%
# Validation mAP (split  5/5) (0.2s): 42.05%
# --------------------------------------------------------------------------------
# Training... Epoch = 37
# Epoch 37, Batch 4/4 (0.4s): Center loss 0.9858, Softmax loss 4.4379, total 5.4262
# Train accuracy: 19.91%
# Validation mAP (split  5/5) (0.2s): 41.69%
# --------------------------------------------------------------------------------
# Training... Epoch = 38
# Epoch 38, Batch 4/4 (0.4s): Center loss 0.9882, Softmax loss 4.4143, total 5.4050
# Train accuracy: 21.06%
# Validation mAP (split  5/5) (0.2s): 42.12%
# --------------------------------------------------------------------------------
# Training... Epoch = 39
# Epoch 39, Batch 4/4 (0.4s): Center loss 0.9439, Softmax loss 4.3939, total 5.3402
# Train accuracy: 23.15%
# Validation mAP (split  5/5) (0.2s): 41.69%
# --------------------------------------------------------------------------------
# Training... Epoch = 40
# Epoch 40, Batch 4/4 (0.4s): Center loss 0.9631, Softmax loss 4.3962, total 5.3617
# Train accuracy: 22.22%
# Validation mAP (split  5/5) (0.3s): 41.50%
# --------------------------------------------------------------------------------
# Training... Epoch = 41
# Epoch 41, Batch 4/4 (0.3s): Center loss 0.9455, Softmax loss 4.3997, total 5.3477
# Train accuracy: 22.92%
# Validation mAP (split  5/5) (0.3s): 41.94%
# --------------------------------------------------------------------------------
# Training... Epoch = 42
# Epoch 42, Batch 4/4 (0.4s): Center loss 0.9233, Softmax loss 4.3796, total 5.3053
# Train accuracy: 22.69%
# Validation mAP (split  5/5) (0.3s): 41.68%
# --------------------------------------------------------------------------------
# Training... Epoch = 43
# Epoch 43, Batch 4/4 (0.3s): Center loss 0.9498, Softmax loss 4.4031, total 5.3553
# Train accuracy: 21.06%
# Validation mAP (split  5/5) (0.3s): 41.71%
# --------------------------------------------------------------------------------
# Training... Epoch = 44
# Epoch 44, Batch 4/4 (0.4s): Center loss 0.9533, Softmax loss 4.3954, total 5.3512
# Train accuracy: 24.31%
# Validation mAP (split  5/5) (0.2s): 41.56%
# --------------------------------------------------------------------------------
# Training... Epoch = 45
# Epoch 45, Batch 4/4 (0.3s): Center loss 0.9551, Softmax loss 4.3727, total 5.3303
# Train accuracy: 22.69%
# Validation mAP (split  5/5) (0.3s): 41.51%
# --------------------------------------------------------------------------------
# Training... Epoch = 46
# Epoch 46, Batch 4/4 (0.3s): Center loss 0.9593, Softmax loss 4.3801, total 5.3419
# Train accuracy: 21.99%
# Validation mAP (split  5/5) (0.3s): 41.80%
# --------------------------------------------------------------------------------
# Training... Epoch = 47
# Epoch 47, Batch 4/4 (0.3s): Center loss 0.9646, Softmax loss 4.3736, total 5.3407
# Train accuracy: 25.23%
# Validation mAP (split  5/5) (0.2s): 41.98%
# --------------------------------------------------------------------------------
# Training... Epoch = 48
# Epoch 48, Batch 4/4 (0.4s): Center loss 0.9260, Softmax loss 4.3788, total 5.3072
# Train accuracy: 21.76%
# Validation mAP (split  5/5) (0.2s): 42.25%
# --------------------------------------------------------------------------------
# Training... Epoch = 49
# Epoch 49, Batch 4/4 (0.4s): Center loss 0.9647, Softmax loss 4.3600, total 5.3272
# Train accuracy: 23.61%
# Validation mAP (split  5/5) (0.3s): 42.00%
# --------------------------------------------------------------------------------
# Training... Epoch = 50
# Epoch 50, Batch 4/4 (0.4s): Center loss 0.9461, Softmax loss 4.3678, total 5.3164
# Train accuracy: 23.84%
# Validation mAP (split  5/5) (0.2s): 42.35%
# --------------------------------------------------------------------------------
# Training... Epoch = 51
# Epoch 51, Batch 4/4 (0.4s): Center loss 0.9453, Softmax loss 4.3699, total 5.3176
# Train accuracy: 21.76%
# Validation mAP (split  5/5) (0.3s): 42.36%
# --------------------------------------------------------------------------------
# Epoch    50: reducing learning rate of group 0 to 1.0000e-06.
# Training... Epoch = 52
# Epoch 52, Batch 4/4 (0.4s): Center loss 0.9815, Softmax loss 4.3453, total 5.3292
# Train accuracy: 25.46%
# Validation mAP (split  5/5) (0.3s): 42.06%
# --------------------------------------------------------------------------------
# Training... Epoch = 53
# Epoch 53, Batch 4/4 (0.4s): Center loss 0.9428, Softmax loss 4.3494, total 5.2946
# Train accuracy: 22.45%
# Validation mAP (split  5/5) (0.2s): 41.95%
# --------------------------------------------------------------------------------
# Training... Epoch = 54
# Epoch 54, Batch 4/4 (0.3s): Center loss 0.9413, Softmax loss 4.3577, total 5.3014
# Train accuracy: 22.92%
# Validation mAP (split  5/5) (0.3s): 41.84%
# --------------------------------------------------------------------------------
# Training... Epoch = 55
# Epoch 55, Batch 4/4 (0.4s): Center loss 0.9343, Softmax loss 4.3801, total 5.3169
# Train accuracy: 23.61%
# Validation mAP (split  5/5) (0.2s): 42.26%
# --------------------------------------------------------------------------------
# Training... Epoch = 56
# Epoch 56, Batch 4/4 (0.4s): Center loss 0.9785, Softmax loss 4.3678, total 5.3488
# Train accuracy: 22.22%
# Validation mAP (split  5/5) (0.3s): 42.18%
# --------------------------------------------------------------------------------
# Training... Epoch = 57
# Epoch 57, Batch 4/4 (0.4s): Center loss 0.9427, Softmax loss 4.3415, total 5.2866
# Train accuracy: 22.69%
# Validation mAP (split  5/5) (0.2s): 41.99%
# --------------------------------------------------------------------------------
# Training... Epoch = 58
# Epoch 58, Batch 4/4 (0.4s): Center loss 0.9444, Softmax loss 4.3459, total 5.2928
# Train accuracy: 22.69%
# Validation mAP (split  5/5) (0.2s): 41.97%
# --------------------------------------------------------------------------------
# Training... Epoch = 59
# Epoch 59, Batch 4/4 (0.3s): Center loss 0.9612, Softmax loss 4.3335, total 5.2971
# Train accuracy: 21.99%
# Validation mAP (split  5/5) (0.2s): 42.02%
# --------------------------------------------------------------------------------
# Training... Epoch = 60
# Epoch 60, Batch 4/4 (0.4s): Center loss 0.9532, Softmax loss 4.3538, total 5.3094
# Train accuracy: 23.61%
# Validation mAP (split  5/5) (0.2s): 41.95%
# --------------------------------------------------------------------------------
# Early stopping at epoch 60.

# %% [markdown]
# # Segunda etapa: fine-tuning da rede completa

# %%
# len(model.parameters) == 53
for i, p in enumerate(model.parameters()):
    p.requires_grad = True

# Verifica que há apenas 2 parâmetros com requires_grad == True
print('Número de camadas que serão otimizadas:', len(list(filter(lambda x: x.requires_grad, model.parameters()))))
# Out:
# Número de camadas que serão otimizadas: 53

# %% [markdown]
# ### Parâmetros de treinamento

# %%
epochs = 500

train_params = {
    'lr': 0.0001,
    'weight_decay': 0.001,
    'lambda_cl': 0.01,
    'alpha': 0.5,
    'num_classes': len(np.unique(datasets['train'].y)),
    'train_loader': dset_loaders['train'],
    'val_loader': dset_loaders['valid'],
    'use_cuda': True,
    'beta_frw': 0.0001,
    'cuda_device': None,
    'patience': 50,
    'scheduler_patience': 20,
    'scheduler_factor': 0.1
}

# %%
try:
    model, train_history = train(epochs, model=model, 
                                 checkpoint_fn='transfer_viper_finetuning_{}.pth', 
                                 **train_params)

except KeyboardInterrupt:
    print('Interrompendo...')
# Out:
# train_args: {'use_cuda': True, 'train_loader': <torch.utils.data.dataloader.DataLoader object at 0x7fd826cd2d68>, 'val_loader': <torch.utils.data.dataloader.DataLoader object at 0x7fd826cd24a8>, 'lambda_cl': 0.01, 'cuda_device': None, 'beta_frw': 0.0001}
#
# Training... Epoch = 1
# Epoch 1, Batch 4/4 (1.1s): Center loss 0.9390, Softmax loss 4.3456, total 5.2870
# Train accuracy: 23.84%
# Validation mAP (split  5/5) (0.3s): 44.37%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: -inf% | 44.37%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 2
# Epoch 2, Batch 4/4 (0.9s): Center loss 0.8890, Softmax loss 4.2222, total 5.1137
# Train accuracy: 30.56%
# Validation mAP (split  5/5) (0.3s): 45.82%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 44.37% | 45.82%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 3
# Epoch 3, Batch 4/4 (1.0s): Center loss 0.7994, Softmax loss 4.0516, total 4.8535
# Train accuracy: 38.89%
# Validation mAP (split  5/5) (0.2s): 46.76%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 45.82% | 46.76%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 4
# Epoch 4, Batch 4/4 (1.0s): Center loss 0.7874, Softmax loss 3.9900, total 4.7800
# Train accuracy: 46.30%
# Validation mAP (split  5/5) (0.3s): 48.03%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 46.76% | 48.03%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 5
# Epoch 5, Batch 4/4 (1.0s): Center loss 0.7284, Softmax loss 3.8964, total 4.6274
# Train accuracy: 47.92%
# Validation mAP (split  5/5) (0.2s): 49.06%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 48.03% | 49.06%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 6
# Epoch 6, Batch 4/4 (1.0s): Center loss 0.6994, Softmax loss 3.8076, total 4.5095
# Train accuracy: 54.17%
# Validation mAP (split  5/5) (0.2s): 49.55%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 49.06% | 49.55%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 7
# Epoch 7, Batch 4/4 (1.0s): Center loss 0.6820, Softmax loss 3.7469, total 4.4315
# Train accuracy: 57.18%
# Validation mAP (split  5/5) (0.2s): 49.93%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 49.55% | 49.93%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 8
# Epoch 8, Batch 4/4 (0.9s): Center loss 0.6502, Softmax loss 3.6283, total 4.2810
# Train accuracy: 61.34%
# Validation mAP (split  5/5) (0.2s): 50.75%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 49.93% | 50.75%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 9
# Epoch 9, Batch 4/4 (1.0s): Center loss 0.6274, Softmax loss 3.5639, total 4.1938
# Train accuracy: 65.05%
# Validation mAP (split  5/5) (0.3s): 52.22%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 50.75% | 52.22%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 10
# Epoch 10, Batch 4/4 (0.9s): Center loss 0.6044, Softmax loss 3.4522, total 4.0590
# Train accuracy: 70.83%
# Validation mAP (split  5/5) (0.2s): 52.81%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 52.22% | 52.81%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 11
# Epoch 11, Batch 4/4 (0.9s): Center loss 0.6148, Softmax loss 3.4211, total 4.0382
# Train accuracy: 71.30%
# Validation mAP (split  5/5) (0.2s): 53.21%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 52.81% | 53.21%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 12
# Epoch 12, Batch 4/4 (1.0s): Center loss 0.5974, Softmax loss 3.2900, total 3.8897
# Train accuracy: 75.93%
# Validation mAP (split  5/5) (0.2s): 53.45%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 53.21% | 53.45%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 13
# Epoch 13, Batch 4/4 (0.9s): Center loss 0.5726, Softmax loss 3.1942, total 3.7690
# Train accuracy: 78.70%
# Validation mAP (split  5/5) (0.2s): 53.27%
# --------------------------------------------------------------------------------
# Training... Epoch = 14
# Epoch 14, Batch 4/4 (0.9s): Center loss 0.5921, Softmax loss 3.1532, total 3.7474
# Train accuracy: 76.62%
# Validation mAP (split  5/5) (0.2s): 53.43%
# --------------------------------------------------------------------------------
# Training... Epoch = 15
# Epoch 15, Batch 4/4 (0.9s): Center loss 0.5535, Softmax loss 3.0468, total 3.6024
# Train accuracy: 82.64%
# Validation mAP (split  5/5) (0.2s): 53.29%
# --------------------------------------------------------------------------------
# Training... Epoch = 16
# Epoch 16, Batch 4/4 (0.9s): Center loss 0.5246, Softmax loss 2.9591, total 3.4856
# Train accuracy: 82.64%
# Validation mAP (split  5/5) (0.3s): 54.23%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 53.45% | 54.23%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 17
# Epoch 17, Batch 4/4 (1.0s): Center loss 0.5476, Softmax loss 2.8820, total 3.4314
# Train accuracy: 87.27%
# Validation mAP (split  5/5) (0.2s): 54.90%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 54.23% | 54.90%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 18
# Epoch 18, Batch 4/4 (1.0s): Center loss 0.5185, Softmax loss 2.7854, total 3.3056
# Train accuracy: 88.66%
# Validation mAP (split  5/5) (0.2s): 55.52%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 54.90% | 55.52%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 19
# Epoch 19, Batch 4/4 (1.0s): Center loss 0.5015, Softmax loss 2.7068, total 3.2100
# Train accuracy: 91.20%
# Validation mAP (split  5/5) (0.2s): 55.60%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 55.52% | 55.60%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 20
# Epoch 20, Batch 4/4 (1.0s): Center loss 0.5038, Softmax loss 2.6233, total 3.1286
# Train accuracy: 90.28%
# Validation mAP (split  5/5) (0.3s): 55.62%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 55.60% | 55.62%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 21
# Epoch 21, Batch 4/4 (1.0s): Center loss 0.5223, Softmax loss 2.5418, total 3.0656
# Train accuracy: 92.59%
# Validation mAP (split  5/5) (0.3s): 55.68%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 55.62% | 55.68%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 22
# Epoch 22, Batch 4/4 (0.9s): Center loss 0.5125, Softmax loss 2.4737, total 2.9876
# Train accuracy: 93.52%
# Validation mAP (split  5/5) (0.2s): 55.72%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 55.68% | 55.72%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 23
# Epoch 23, Batch 4/4 (1.0s): Center loss 0.5007, Softmax loss 2.3942, total 2.8962
# Train accuracy: 94.44%
# Validation mAP (split  5/5) (0.2s): 56.86%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 55.72% | 56.86%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 24
# Epoch 24, Batch 4/4 (0.9s): Center loss 0.4979, Softmax loss 2.2984, total 2.7975
# Train accuracy: 94.44%
# Validation mAP (split  5/5) (0.2s): 58.02%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 56.86% | 58.02%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 25
# Epoch 25, Batch 4/4 (0.9s): Center loss 0.4978, Softmax loss 2.2334, total 2.7323
# Train accuracy: 95.14%
# Validation mAP (split  5/5) (0.2s): 57.10%
# --------------------------------------------------------------------------------
# Training... Epoch = 26
# Epoch 26, Batch 4/4 (0.9s): Center loss 0.4913, Softmax loss 2.1516, total 2.6439
# Train accuracy: 96.30%
# Validation mAP (split  5/5) (0.2s): 56.99%
# --------------------------------------------------------------------------------
# Training... Epoch = 27
# Epoch 27, Batch 4/4 (0.9s): Center loss 0.4878, Softmax loss 2.0480, total 2.5367
# Train accuracy: 96.99%
# Validation mAP (split  5/5) (0.3s): 57.27%
# --------------------------------------------------------------------------------
# Training... Epoch = 28
# Epoch 28, Batch 4/4 (1.0s): Center loss 0.4928, Softmax loss 2.0027, total 2.4963
# Train accuracy: 98.38%
# Validation mAP (split  5/5) (0.2s): 58.32%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 58.02% | 58.32%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 29
# Epoch 29, Batch 4/4 (0.9s): Center loss 0.5181, Softmax loss 1.9533, total 2.4722
# Train accuracy: 97.69%
# Validation mAP (split  5/5) (0.2s): 57.15%
# --------------------------------------------------------------------------------
# Training... Epoch = 30
# Epoch 30, Batch 4/4 (1.0s): Center loss 0.4696, Softmax loss 1.8100, total 2.2802
# Train accuracy: 98.61%
# Validation mAP (split  5/5) (0.2s): 56.71%
# --------------------------------------------------------------------------------
# Training... Epoch = 31
# Epoch 31, Batch 4/4 (0.9s): Center loss 0.4950, Softmax loss 1.7566, total 2.2522
# Train accuracy: 98.61%
# Validation mAP (split  5/5) (0.2s): 56.90%
# --------------------------------------------------------------------------------
# Training... Epoch = 32
# Epoch 32, Batch 4/4 (1.0s): Center loss 0.4884, Softmax loss 1.7191, total 2.2080
# Train accuracy: 98.61%
# Validation mAP (split  5/5) (0.2s): 56.80%
# --------------------------------------------------------------------------------
# Training... Epoch = 33
# Epoch 33, Batch 4/4 (1.0s): Center loss 0.4972, Softmax loss 1.6241, total 2.1218
# Train accuracy: 99.31%
# Validation mAP (split  5/5) (0.2s): 56.44%
# --------------------------------------------------------------------------------
# Training... Epoch = 34
# Epoch 34, Batch 4/4 (0.9s): Center loss 0.4794, Softmax loss 1.5626, total 2.0424
# Train accuracy: 99.54%
# Validation mAP (split  5/5) (0.2s): 57.34%
# --------------------------------------------------------------------------------
# Training... Epoch = 35
# Epoch 35, Batch 4/4 (1.0s): Center loss 0.4917, Softmax loss 1.4940, total 1.9860
# Train accuracy: 99.54%
# Validation mAP (split  5/5) (0.2s): 56.72%
# --------------------------------------------------------------------------------
# Training... Epoch = 36
# Epoch 36, Batch 4/4 (1.0s): Center loss 0.4903, Softmax loss 1.4198, total 1.9104
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 57.05%
# --------------------------------------------------------------------------------
# Training... Epoch = 37
# Epoch 37, Batch 4/4 (1.0s): Center loss 0.4715, Softmax loss 1.3583, total 1.8301
# Train accuracy: 99.77%
# Validation mAP (split  5/5) (0.2s): 56.85%
# --------------------------------------------------------------------------------
# Training... Epoch = 38
# Epoch 38, Batch 4/4 (0.9s): Center loss 0.4657, Softmax loss 1.2866, total 1.7525
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.3s): 56.00%
# --------------------------------------------------------------------------------
# Training... Epoch = 39
# Epoch 39, Batch 4/4 (1.0s): Center loss 0.4671, Softmax loss 1.2330, total 1.7003
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.3s): 57.72%
# --------------------------------------------------------------------------------
# Training... Epoch = 40
# Epoch 40, Batch 4/4 (1.0s): Center loss 0.4655, Softmax loss 1.1750, total 1.6406
# Train accuracy: 99.54%
# Validation mAP (split  5/5) (0.2s): 57.04%
# --------------------------------------------------------------------------------
# Training... Epoch = 41
# Epoch 41, Batch 4/4 (1.0s): Center loss 0.4549, Softmax loss 1.1302, total 1.5853
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 57.35%
# --------------------------------------------------------------------------------
# Training... Epoch = 42
# Epoch 42, Batch 4/4 (1.0s): Center loss 0.4644, Softmax loss 1.0577, total 1.5223
# Train accuracy: 99.77%
# Validation mAP (split  5/5) (0.3s): 57.41%
# --------------------------------------------------------------------------------
# Training... Epoch = 43
# Epoch 43, Batch 4/4 (1.0s): Center loss 0.4560, Softmax loss 1.0341, total 1.4903
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.3s): 56.26%
# --------------------------------------------------------------------------------
# Training... Epoch = 44
# Epoch 44, Batch 4/4 (0.9s): Center loss 0.4746, Softmax loss 0.9610, total 1.4357
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 55.79%
# --------------------------------------------------------------------------------
# Training... Epoch = 45
# Epoch 45, Batch 4/4 (1.0s): Center loss 0.4440, Softmax loss 0.9052, total 1.3493
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 55.64%
# --------------------------------------------------------------------------------
# Training... Epoch = 46
# Epoch 46, Batch 4/4 (1.0s): Center loss 0.4677, Softmax loss 0.8793, total 1.3471
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 56.27%
# --------------------------------------------------------------------------------
# Training... Epoch = 47
# Epoch 47, Batch 4/4 (0.9s): Center loss 0.4619, Softmax loss 0.8350, total 1.2970
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 56.78%
# --------------------------------------------------------------------------------
# Training... Epoch = 48
# Epoch 48, Batch 4/4 (0.9s): Center loss 0.4363, Softmax loss 0.7758, total 1.2121
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 55.85%
# --------------------------------------------------------------------------------
# Training... Epoch = 49
# Epoch 49, Batch 4/4 (1.0s): Center loss 0.4495, Softmax loss 0.7595, total 1.2090
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 56.32%
# --------------------------------------------------------------------------------
# Epoch    48: reducing learning rate of group 0 to 1.0000e-05.
# Training... Epoch = 50
# Epoch 50, Batch 4/4 (0.9s): Center loss 0.4610, Softmax loss 0.7226, total 1.1837
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 56.08%
# --------------------------------------------------------------------------------
# Training... Epoch = 51
# Epoch 51, Batch 4/4 (1.0s): Center loss 0.4278, Softmax loss 0.7108, total 1.1386
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 55.24%
# --------------------------------------------------------------------------------
# Training... Epoch = 52
# Epoch 52, Batch 4/4 (1.0s): Center loss 0.4445, Softmax loss 0.7076, total 1.1520
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.3s): 55.48%
# --------------------------------------------------------------------------------
# Training... Epoch = 53
# Epoch 53, Batch 4/4 (1.0s): Center loss 0.4324, Softmax loss 0.6927, total 1.1251
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 55.69%
# --------------------------------------------------------------------------------
# Training... Epoch = 54
# Epoch 54, Batch 4/4 (1.0s): Center loss 0.4654, Softmax loss 0.7281, total 1.1934
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 56.04%
# --------------------------------------------------------------------------------
# Training... Epoch = 55
# Epoch 55, Batch 4/4 (0.9s): Center loss 0.4342, Softmax loss 0.6921, total 1.1263
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 56.26%
# --------------------------------------------------------------------------------
# Training... Epoch = 56
# Epoch 56, Batch 4/4 (1.0s): Center loss 0.4301, Softmax loss 0.7009, total 1.1310
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 56.25%
# --------------------------------------------------------------------------------
# Training... Epoch = 57
# Epoch 57, Batch 4/4 (0.9s): Center loss 0.4404, Softmax loss 0.7054, total 1.1458
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 56.03%
# --------------------------------------------------------------------------------
# Training... Epoch = 58
# Epoch 58, Batch 4/4 (0.9s): Center loss 0.4355, Softmax loss 0.6845, total 1.1200
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 55.62%
# --------------------------------------------------------------------------------
# Training... Epoch = 59
# Epoch 59, Batch 4/4 (0.9s): Center loss 0.4367, Softmax loss 0.6806, total 1.1172
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.3s): 55.43%
# --------------------------------------------------------------------------------
# Training... Epoch = 60
# Epoch 60, Batch 4/4 (1.0s): Center loss 0.4214, Softmax loss 0.6827, total 1.1041
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.3s): 55.98%
# --------------------------------------------------------------------------------
# Training... Epoch = 61
# Epoch 61, Batch 4/4 (1.0s): Center loss 0.4945, Softmax loss 0.7210, total 1.2156
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 55.34%
# --------------------------------------------------------------------------------
# Training... Epoch = 62
# Epoch 62, Batch 4/4 (1.0s): Center loss 0.4432, Softmax loss 0.6760, total 1.1192
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 55.55%
# --------------------------------------------------------------------------------
# Training... Epoch = 63
# Epoch 63, Batch 4/4 (1.0s): Center loss 0.4261, Softmax loss 0.6663, total 1.0924
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.3s): 54.89%
# --------------------------------------------------------------------------------
# Training... Epoch = 64
# Epoch 64, Batch 4/4 (0.9s): Center loss 0.4370, Softmax loss 0.6814, total 1.1185
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.3s): 55.97%
# --------------------------------------------------------------------------------
# Training... Epoch = 65
# Epoch 65, Batch 4/4 (1.0s): Center loss 0.4462, Softmax loss 0.6771, total 1.1233
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.3s): 56.02%
# --------------------------------------------------------------------------------
# Training... Epoch = 66
# Epoch 66, Batch 4/4 (1.0s): Center loss 0.4230, Softmax loss 0.6427, total 1.0658
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 55.82%
# --------------------------------------------------------------------------------
# Training... Epoch = 67
# Epoch 67, Batch 4/4 (1.0s): Center loss 0.4309, Softmax loss 0.6713, total 1.1022
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 55.97%
# --------------------------------------------------------------------------------
# Training... Epoch = 68
# Epoch 68, Batch 4/4 (0.9s): Center loss 0.4287, Softmax loss 0.6382, total 1.0669
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.3s): 56.65%
# --------------------------------------------------------------------------------
# Training... Epoch = 69
# Epoch 69, Batch 4/4 (1.1s): Center loss 0.4084, Softmax loss 0.6317, total 1.0401
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.3s): 56.90%
# --------------------------------------------------------------------------------
# Training... Epoch = 70
# Epoch 70, Batch 4/4 (1.0s): Center loss 0.4038, Softmax loss 0.6255, total 1.0292
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.3s): 56.24%
# --------------------------------------------------------------------------------
# Epoch    69: reducing learning rate of group 0 to 1.0000e-06.
# Training... Epoch = 71
# Epoch 71, Batch 4/4 (1.0s): Center loss 0.4266, Softmax loss 0.6337, total 1.0602
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.4s): 56.70%
# --------------------------------------------------------------------------------
# Training... Epoch = 72
# Epoch 72, Batch 4/4 (1.0s): Center loss 0.4333, Softmax loss 0.6420, total 1.0753
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 56.76%
# --------------------------------------------------------------------------------
# Training... Epoch = 73
# Epoch 73, Batch 4/4 (1.0s): Center loss 0.4134, Softmax loss 0.6216, total 1.0350
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.3s): 57.60%
# --------------------------------------------------------------------------------
# Training... Epoch = 74
# Epoch 74, Batch 4/4 (1.0s): Center loss 0.4136, Softmax loss 0.6410, total 1.0545
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 56.39%
# --------------------------------------------------------------------------------
# Training... Epoch = 75
# Epoch 75, Batch 4/4 (0.9s): Center loss 0.4032, Softmax loss 0.6243, total 1.0275
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 56.42%
# --------------------------------------------------------------------------------
# Training... Epoch = 76
# Epoch 76, Batch 4/4 (1.0s): Center loss 0.4239, Softmax loss 0.6428, total 1.0667
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 56.32%
# --------------------------------------------------------------------------------
# Training... Epoch = 77
# Epoch 77, Batch 4/4 (1.0s): Center loss 0.4388, Softmax loss 0.6448, total 1.0836
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 56.42%
# --------------------------------------------------------------------------------
# Training... Epoch = 78
# Epoch 78, Batch 4/4 (1.0s): Center loss 0.4202, Softmax loss 0.6416, total 1.0618
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 56.33%
# --------------------------------------------------------------------------------
# Training... Epoch = 79
# Epoch 79, Batch 4/4 (1.0s): Center loss 0.4219, Softmax loss 0.6518, total 1.0737
# Train accuracy: 100.00%
# Validation mAP (split  5/5) (0.2s): 56.52%
# --------------------------------------------------------------------------------
# Early stopping at epoch 79.
