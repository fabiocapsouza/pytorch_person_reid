# %% [markdown]
# # Treinamento - Market-1501

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
import torch
import torch as tc
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from  torch.utils.data import DataLoader
import torch.optim.lr_scheduler as lr_scheduler
import matplotlib.pyplot as plt
# %matplotlib inline
import torchvision.datasets as dset
import numpy as np
import cv2

from center_loss import CenterLoss
from frw import L2_penalty_with_constant
from reid_model import ReID_Net
from datasets import Market1501
from custom_transforms import RandomTranslation
from evaluation import calculate_mAP, generate_query
from utils import MetricAverager, save_checkpoint, load_checkpoint
import time
import shutil

# %% [markdown]
# ## Dataset, transformações de _data augmentation_ e DataLoaders

# %%
data_transforms = {
    'train': transforms.Compose([
        RandomTranslation(0.1),   # translação em numpy array
        transforms.ToPILImage(),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),    # range [0.0, 1.0]
        transforms.Lambda(lambda t: t/0.5 - 1)    # range [-1.0, 1.0]
    ]),
    'valid': transforms.Compose([
        transforms.ToTensor(),
        transforms.Lambda(lambda t: t/0.5 - 1)
    ])
}

# %%
datasets = {
    'train': Market1501('../reid/datasets/market_train_correct.npz', transform=data_transforms['train']),
    'valid': Market1501('../reid/datasets/market_train_correct.npz', train=False, 
                    transform=data_transforms['valid']),
    'test': Market1501('../reid/datasets/market_test_correct.npz', train=False, test=True,
                    transform=data_transforms['valid']),
}

batch_size = 128
dset_loaders = {
    'train': DataLoader(datasets['train'], batch_size=batch_size, shuffle=True, num_workers=4),
    'valid': DataLoader(datasets['valid'], batch_size=batch_size, shuffle=False, num_workers=4),
    'test': DataLoader(datasets['test'], batch_size=batch_size, shuffle=False, num_workers=4)
}

# %%
print('Train data:')
print(datasets['train'].X.shape, datasets['train'].X.dtype, datasets['train'].X.min(), datasets['train'].X.max())
print(datasets['train'].y.shape, datasets['train'].y.dtype, datasets['train'].y.min(), datasets['train'].y.max())
print('\nValidation data:')
print(datasets['valid'].X.shape, datasets['valid'].X.dtype, datasets['valid'].X.min(), datasets['valid'].X.max())
print(datasets['valid'].y.shape, datasets['valid'].y.dtype, datasets['valid'].y.min(), datasets['valid'].y.max())
print('\nTest data:')
print(datasets['test'].X.shape, datasets['test'].X.dtype, datasets['test'].X.min(), datasets['test'].X.max())
print(datasets['test'].y.shape, datasets['test'].y.dtype, datasets['test'].y.min(), datasets['test'].y.max())
# Out:
# Train data:
# (11253, 128, 48, 3) uint8 0 255
# (11253,) int64 0 650
#
# Validation data:
# (1683, 128, 48, 3) uint8 0 255
# (1683,) int64 0 99
#
# Test data:
# (16483, 128, 48, 3) uint8 0 255
# (16483,) int64 1 750

# %%
len(dset_loaders['train']), len(dset_loaders['valid']), len(dset_loaders['test'])
# Out:
# (88, 14, 129)

# %%
dset_loaders['valid'].dataset.cam_ids[:10]
# Out:
# array([0, 0, 0, 3, 3, 3, 4, 4, 4, 1])

# %%
lambda_cl = 0.01
alpha = 0.5
num_classes = len(np.unique(datasets['train'].y))
print('num_classes: ', num_classes)

epochs = 500
beta_frw = 0.0001

lr = 0.001
weight_decay = 0.001
# Out:
# num_classes:  651

# %% [markdown]
# ## Funções de treinamento
#
# ### Uma época

# %%
def train_epoch(model, optimizer, epoch, criterions, train_loader, val_loader, use_cuda, lambda_cl, beta_frw,
                query_splits, cuda_device=None):
    print("Training... Epoch = %d" % epoch)

    train_accum = 0
    n_train_samples = 0
    val_accum = 0
    n_val_samples = 0
    
    tlosses = {
        'center_loss': MetricAverager(),
        'softmax_loss': MetricAverager(),
        'total': MetricAverager(),
    }
    
    #train
    model.train(True)
    t0 = time.time()
    for i,(data, target) in enumerate(train_loader):
        
        if use_cuda:
            data = data.cuda()
            target = target.cuda()
        data, target = Variable(data), Variable(target)
        
        
        features, pred = model(data)
        
        # Softmax loss + center loss
        softmax_loss = criterions[0](pred, target)
        center_loss = lambda_cl * criterions[1](features, target)
        loss = softmax_loss + center_loss
        
        # Acrescenta a penalização L2 na camada FRW
        for (name, p) in model.named_parameters():
            if name == 'frw.weight' or name == 'fc_embeddings.3.weight':
                loss += beta_frw * criterions[2](p)
        
        _, preds = torch.max(pred.data, 1)
        correct = (preds == target.data).sum()
        train_accum += correct
        n_train_samples += target.size(0)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        tlosses['center_loss'].update(center_loss.data.cpu().numpy()[0])
        tlosses['softmax_loss'].update(softmax_loss.data.cpu().numpy()[0])
        tlosses['total'].update(loss.data.cpu().numpy()[0])
        
        t1 = time.time() - t0
        train_string = 'Epoch {}, Batch {}/{} ({:.1f}s): Center loss {:.4f}, Softmax loss {:.4f}, ' \
            'total {:.4f}'.format(epoch, i+1, len(train_loader), t1, tlosses['center_loss'], 
                                  tlosses['softmax_loss'], tlosses['total'])
        print(train_string, end='\r' if i < len(train_loader)-1 else '\n')
    
    train_acc = train_accum / n_train_samples
    print('Train accuracy: {:.2%}'.format(train_acc))
        
    # Validation: in the validation phase, we extract the features of all the validation images.
    # Then, we calculate the pairwise euclidian distance for all samples and calculate
    # the top-1, top-5 and top-10 CMC curves using single-gallery-shot setting: the query and
    # gallery sets have images from different camera views and, for each person identity, one image 
    # is randomly selected for each set. This is done for each query split configuration.
    
    t0 = time.time()
    model.train(False)
    
    val_feats = []
    val_pids = []
    
    valid_metrics = {
        'map': MetricAverager(),
    }
    
    for i, (data, target) in enumerate(val_loader):
        
        if use_cuda:
            data = data.cuda()
        data = Variable(data, volatile=True)

        features, pred = model(data)
        val_feats.append(features.data.cpu())
        
    val_feats = torch.cat(val_feats)
    
    # Calculates mAP for the validation set, as if it was a Query-Gallery set
    val_dataset = val_loader.dataset
    val_cam_ids = val_dataset.cam_ids
    y_val = val_dataset.y
    
    # Gallery: may or may not include distractors
    y_gallery = y_val
    gal_cam_ids = val_cam_ids
    
    for i, query_indices_by_cam in enumerate(query_splits):
        #query_indices_by_cam = generate_query(y_val, val_cam_ids)
        val_map = calculate_mAP(query_indices_by_cam, val_feats, y_gallery, gal_cam_ids)
        valid_metrics['map'].update(val_map)

        t1 = time.time() - t0
        print('Validation mAP (split {:>2}/{}) ({:.1f}s): {:.2%}'.format(i+1, len(query_splits),
                t1, valid_metrics['map'].mean), end='\r' if i+1 < len(query_splits) else '\n')
        
    print('-'*80)
        
    
    metrics = {
        'train': {
            'losses': {
                'center_loss': tlosses['center_loss'].mean,
                'softmax_loss': tlosses['softmax_loss'].mean,
                'total': tlosses['total'].mean,
            },
            'accuracy': train_acc,
        },
        'valid': {
            'map': valid_metrics['map'].mean
        }
    }
    
    return metrics

# %% [markdown]
# ### Treinamento total

# %%
def train(epochs, model=None, resume=None, checkpoint_fn=None, **train_args):
    best_val_loss = None
    last_epoch = 0
    
    train_history = []
    
    use_cuda = train_args.get('use_cuda')
    
    if model is None:
        num_classes = train_args.pop('num_classes')
        model = ReID_Net(num_classes)
    
    if resume is not None:
        scheduler, last_epoch, best_val_loss, train_history = load_checkpoint(resume, model, optimizer4nn)
        num_classes = model.centers.size(0)
    
    # NLLLoss
    nllloss = nn.NLLLoss() #CrossEntropyLoss = log_softmax + NLLLoss
    # CenterLoss
    loss_weight = 1.0

    # FRW L2 penalty
    frw_l2_penalty = L2_penalty_with_constant(200)
    
    if use_cuda:
        nllloss = nllloss.cuda()
        model = model.cuda()
        frw_l2_penalty = frw_l2_penalty.cuda()
        
    
    alpha = train_args.pop('alpha')

    centerloss = CenterLoss(model, model.centers, num_classes, alpha)
    criterions = [nllloss, centerloss, frw_l2_penalty]

    # optimzer4nn
    lr = train_args.pop('lr')
    weight_decay = train_args.pop('weight_decay')
    optimizer4nn = optim.Adam(model.parameters(),lr=lr, weight_decay=weight_decay)
    
    # LR Scheduler
    scheduler_patience = train_args.pop('scheduler_patience', 35)
    scheduler_factor = train_args.pop('scheduler_factor', 0.1)
    scheduler = lr_scheduler.ReduceLROnPlateau(optimizer4nn, mode='max', patience=scheduler_patience, 
                                               factor=scheduler_factor, verbose=True)
        
    max_val_map = best_val_loss or -np.Inf
    
    patience = train_args.pop('patience', 50)
    no_improve = 0
    
    print('train_args:', train_args)
    
    # Gera os splits de query e gallery que serão usados no CMC de validação
    val_dataset = train_args['val_loader'].dataset
    query_splits = []
    for i in range(10):
        query_splits.append(generate_query(val_dataset.y, val_dataset.cam_ids))
    
    for epoch in range(last_epoch+1, epochs):

        metrics = train_epoch(model, optimizer4nn, epoch, criterions, query_splits=query_splits, **train_args)
        
        scheduler.step(metrics['valid']['map'])
        train_history.append(metrics)
        
        if metrics['valid']['map'] > max_val_map:
            print("Max. Valid. mAP / Epoch's Valid. mAP: {:.2%} | {:.2%}".format(
                max_val_map, metrics['valid']['map']))
            print('Salvando melhor modelo...')
            max_val_map = metrics['valid']['map']
            state = {
                'epoch': epoch,
                'state_dict': model.state_dict(),
                'best_val_loss': max_val_map,
                'train_softmax_loss': metrics['train']['losses']['softmax_loss'],
                'history': train_history,
            }
            opts = {'is_best': False}
            if checkpoint_fn is not None:
                opts.update({'filename': checkpoint_fn.format(epoch+1)})
            save_checkpoint(state, **opts)
            no_improve = 0
            print('-'*80)
        else:
            no_improve += 1
            if no_improve > patience:
                print('Early stopping at epoch {}.'.format(epoch))
                break
                
                
    return model, train_history

# %% [markdown]
# ## Loop de treinamento

# %%
train_params = {
    'train_loader': dset_loaders['train'],
    'val_loader': dset_loaders['valid'],
    'num_classes': len(np.unique(datasets['train'].y)),
    'lr': 0.001,
    'weight_decay': 0.001,
    'use_cuda': True,
    'lambda_cl': 0.01,
    'alpha': 0.5,
    'beta_frw': 0.0001,
    'cuda_device': None,
    'patience': 50,
    'scheduler_patience': 35,
    'scheduler_factor': 0.1,
}

# %%
try:
    model, hist = train(epochs, model=None, checkpoint_fn='market1501_map_epoch_{}.pth', **train_params)
except KeyboardInterrupt:
    print('Interrompendo...')
# Out:
# train_args: {'train_loader': <torch.utils.data.dataloader.DataLoader object at 0x7ff922478d68>, 'beta_frw': 0.0001, 'val_loader': <torch.utils.data.dataloader.DataLoader object at 0x7ff922478e48>, 'lambda_cl': 0.01, 'use_cuda': True, 'cuda_device': None}
# Training... Epoch = 1
# Epoch 1, Batch 88/88 (19.9s): Center loss 0.5211, Softmax loss 5.4276, total 6.0953
# Train accuracy: 6.98%
# Validation mAP (split 10/10) (4.8s): 35.88%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: -inf% | 35.88%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 2
# Epoch 2, Batch 88/88 (20.1s): Center loss 0.1684, Softmax loss 3.7638, total 3.9547
# Train accuracy: 24.96%
# Validation mAP (split 10/10) (3.3s): 47.56%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 35.88% | 47.56%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 3
# Epoch 3, Batch 88/88 (19.7s): Center loss 0.2316, Softmax loss 2.6458, total 2.8840
# Train accuracy: 44.74%
# Validation mAP (split 10/10) (3.0s): 53.82%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 47.56% | 53.82%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 4
# Epoch 4, Batch 88/88 (19.6s): Center loss 0.2880, Softmax loss 1.8053, total 2.0967
# Train accuracy: 61.84%
# Validation mAP (split 10/10) (2.8s): 60.27%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 53.82% | 60.27%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 5
# Epoch 5, Batch 88/88 (19.6s): Center loss 0.3278, Softmax loss 1.2636, total 1.5927
# Train accuracy: 74.26%
# Validation mAP (split 10/10) (2.6s): 63.92%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 60.27% | 63.92%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 6
# Epoch 6, Batch 88/88 (19.6s): Center loss 0.3462, Softmax loss 0.9062, total 1.2526
# Train accuracy: 82.47%
# Validation mAP (split 10/10) (2.6s): 67.38%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 63.92% | 67.38%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 7
# Epoch 7, Batch 88/88 (19.7s): Center loss 0.3511, Softmax loss 0.7058, total 1.0569
# Train accuracy: 86.92%
# Validation mAP (split 10/10) (2.6s): 68.64%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 67.38% | 68.64%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 8
# Epoch 8, Batch 88/88 (19.7s): Center loss 0.3504, Softmax loss 0.5821, total 0.9328
# Train accuracy: 90.17%
# Validation mAP (split 10/10) (2.5s): 71.46%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 68.64% | 71.46%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 9
# Epoch 9, Batch 88/88 (19.7s): Center loss 0.3438, Softmax loss 0.4803, total 0.8244
# Train accuracy: 92.58%
# Validation mAP (split 10/10) (2.6s): 70.67%
# --------------------------------------------------------------------------------
# Training... Epoch = 10
# Epoch 10, Batch 88/88 (19.7s): Center loss 0.3378, Softmax loss 0.4269, total 0.7652
# Train accuracy: 93.85%
# Validation mAP (split 10/10) (2.5s): 72.50%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 71.46% | 72.50%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 11
# Epoch 11, Batch 88/88 (19.7s): Center loss 0.3307, Softmax loss 0.3777, total 0.7089
# Train accuracy: 95.03%
# Validation mAP (split 10/10) (2.4s): 70.89%
# --------------------------------------------------------------------------------
# Training... Epoch = 12
# Epoch 12, Batch 88/88 (19.7s): Center loss 0.3190, Softmax loss 0.3344, total 0.6540
# Train accuracy: 96.19%
# Validation mAP (split 10/10) (2.5s): 73.70%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 72.50% | 73.70%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 13
# Epoch 13, Batch 88/88 (19.7s): Center loss 0.3163, Softmax loss 0.3132, total 0.6301
# Train accuracy: 96.66%
# Validation mAP (split 10/10) (2.6s): 72.45%
# --------------------------------------------------------------------------------
# Training... Epoch = 14
# Epoch 14, Batch 88/88 (19.7s): Center loss 0.3136, Softmax loss 0.3068, total 0.6209
# Train accuracy: 96.71%
# Validation mAP (split 10/10) (2.6s): 72.50%
# --------------------------------------------------------------------------------
# Training... Epoch = 15
# Epoch 15, Batch 88/88 (19.8s): Center loss 0.3087, Softmax loss 0.2865, total 0.5959
# Train accuracy: 97.33%
# Validation mAP (split 10/10) (2.5s): 73.19%
# --------------------------------------------------------------------------------
# Training... Epoch = 16
# Epoch 16, Batch 88/88 (19.7s): Center loss 0.3058, Softmax loss 0.2694, total 0.5758
# Train accuracy: 97.45%
# Validation mAP (split 10/10) (2.5s): 73.98%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 73.70% | 73.98%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 17
# Epoch 17, Batch 88/88 (19.7s): Center loss 0.2963, Softmax loss 0.2514, total 0.5485
# Train accuracy: 97.85%
# Validation mAP (split 10/10) (2.4s): 74.31%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 73.98% | 74.31%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 18
# Epoch 18, Batch 88/88 (19.7s): Center loss 0.2988, Softmax loss 0.2536, total 0.5531
# Train accuracy: 97.75%
# Validation mAP (split 10/10) (2.5s): 73.12%
# --------------------------------------------------------------------------------
# Training... Epoch = 19
# Epoch 19, Batch 88/88 (19.8s): Center loss 0.2958, Softmax loss 0.2430, total 0.5396
# Train accuracy: 98.00%
# Validation mAP (split 10/10) (2.5s): 72.47%
# --------------------------------------------------------------------------------
# Training... Epoch = 20
# Epoch 20, Batch 88/88 (19.8s): Center loss 0.2921, Softmax loss 0.2340, total 0.5269
# Train accuracy: 98.12%
# Validation mAP (split 10/10) (2.6s): 70.21%
# --------------------------------------------------------------------------------
# Training... Epoch = 21
# Epoch 21, Batch 88/88 (19.8s): Center loss 0.2960, Softmax loss 0.2334, total 0.5301
# Train accuracy: 98.12%
# Validation mAP (split 10/10) (2.4s): 75.24%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 74.31% | 75.24%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 22
# Epoch 22, Batch 88/88 (19.7s): Center loss 0.2897, Softmax loss 0.2189, total 0.5094
# Train accuracy: 98.33%
# Validation mAP (split 10/10) (2.6s): 74.77%
# --------------------------------------------------------------------------------
# Training... Epoch = 23
# Epoch 23, Batch 88/88 (19.8s): Center loss 0.2867, Softmax loss 0.2143, total 0.5019
# Train accuracy: 98.46%
# Validation mAP (split 10/10) (2.5s): 74.02%
# --------------------------------------------------------------------------------
# Training... Epoch = 24
# Epoch 24, Batch 88/88 (19.6s): Center loss 0.2882, Softmax loss 0.2127, total 0.5018
# Train accuracy: 98.52%
# Validation mAP (split 10/10) (2.4s): 75.22%
# --------------------------------------------------------------------------------
# Training... Epoch = 25
# Epoch 25, Batch 88/88 (19.6s): Center loss 0.2863, Softmax loss 0.2058, total 0.4930
# Train accuracy: 98.80%
# Validation mAP (split 10/10) (2.4s): 75.31%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 75.24% | 75.31%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 26
# Epoch 26, Batch 88/88 (19.6s): Center loss 0.2814, Softmax loss 0.1952, total 0.4776
# Train accuracy: 98.97%
# Validation mAP (split 10/10) (2.6s): 72.65%
# --------------------------------------------------------------------------------
# Training... Epoch = 27
# Epoch 27, Batch 88/88 (19.6s): Center loss 0.2864, Softmax loss 0.2033, total 0.4907
# Train accuracy: 98.62%
# Validation mAP (split 10/10) (2.5s): 74.20%
# --------------------------------------------------------------------------------
# Training... Epoch = 28
# Epoch 28, Batch 88/88 (19.6s): Center loss 0.2799, Softmax loss 0.1884, total 0.4694
# Train accuracy: 98.97%
# Validation mAP (split 10/10) (2.5s): 73.17%
# --------------------------------------------------------------------------------
# Training... Epoch = 29
# Epoch 29, Batch 88/88 (19.6s): Center loss 0.2766, Softmax loss 0.1817, total 0.4593
# Train accuracy: 99.05%
# Validation mAP (split 10/10) (2.5s): 72.91%
# --------------------------------------------------------------------------------
# Training... Epoch = 30
# Epoch 30, Batch 88/88 (19.6s): Center loss 0.2846, Softmax loss 0.1903, total 0.4759
# Train accuracy: 98.83%
# Validation mAP (split 10/10) (2.5s): 73.85%
# --------------------------------------------------------------------------------
# Training... Epoch = 31
# Epoch 31, Batch 88/88 (19.6s): Center loss 0.2832, Softmax loss 0.1879, total 0.4723
# Train accuracy: 98.94%
# Validation mAP (split 10/10) (2.5s): 75.25%
# --------------------------------------------------------------------------------
# Training... Epoch = 32
# Epoch 32, Batch 88/88 (19.7s): Center loss 0.2811, Softmax loss 0.1788, total 0.4610
# Train accuracy: 99.12%
# Validation mAP (split 10/10) (2.5s): 75.15%
# --------------------------------------------------------------------------------
# Training... Epoch = 33
# Epoch 33, Batch 88/88 (19.6s): Center loss 0.2786, Softmax loss 0.1756, total 0.4555
# Train accuracy: 99.19%
# Validation mAP (split 10/10) (2.5s): 75.13%
# --------------------------------------------------------------------------------
# Training... Epoch = 34
# Epoch 34, Batch 88/88 (19.6s): Center loss 0.2798, Softmax loss 0.1758, total 0.4569
# Train accuracy: 98.97%
# Validation mAP (split 10/10) (2.6s): 73.10%
# --------------------------------------------------------------------------------
# Training... Epoch = 35
# Epoch 35, Batch 88/88 (19.6s): Center loss 0.2820, Softmax loss 0.1729, total 0.4562
# Train accuracy: 99.14%
# Validation mAP (split 10/10) (2.5s): 74.66%
# --------------------------------------------------------------------------------
# Training... Epoch = 36
# Epoch 36, Batch 88/88 (19.6s): Center loss 0.2771, Softmax loss 0.1671, total 0.4456
# Train accuracy: 99.20%
# Validation mAP (split 10/10) (2.5s): 74.85%
# --------------------------------------------------------------------------------
# Training... Epoch = 37
# Epoch 37, Batch 88/88 (19.7s): Center loss 0.2832, Softmax loss 0.1708, total 0.4554
# Train accuracy: 99.24%
# Validation mAP (split 10/10) (2.5s): 74.44%
# --------------------------------------------------------------------------------
# Training... Epoch = 38
# Epoch 38, Batch 88/88 (19.6s): Center loss 0.2824, Softmax loss 0.1707, total 0.4545
# Train accuracy: 99.01%
# Validation mAP (split 10/10) (2.5s): 73.16%
# --------------------------------------------------------------------------------
# Training... Epoch = 39
# Epoch 39, Batch 88/88 (19.6s): Center loss 0.2804, Softmax loss 0.1671, total 0.4490
# Train accuracy: 99.14%
# Validation mAP (split 10/10) (2.5s): 72.73%
# --------------------------------------------------------------------------------
# Training... Epoch = 40
# Epoch 40, Batch 88/88 (19.6s): Center loss 0.2695, Softmax loss 0.1497, total 0.4208
# Train accuracy: 99.28%
# Validation mAP (split 10/10) (2.4s): 75.62%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 75.31% | 75.62%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 41
# Epoch 41, Batch 88/88 (19.6s): Center loss 0.2727, Softmax loss 0.1554, total 0.4296
# Train accuracy: 99.38%
# Validation mAP (split 10/10) (2.5s): 74.36%
# --------------------------------------------------------------------------------
# Training... Epoch = 42
# Epoch 42, Batch 88/88 (19.6s): Center loss 0.2926, Softmax loss 0.1738, total 0.4680
# Train accuracy: 98.92%
# Validation mAP (split 10/10) (2.5s): 73.89%
# --------------------------------------------------------------------------------
# Training... Epoch = 43
# Epoch 43, Batch 88/88 (19.6s): Center loss 0.2798, Softmax loss 0.1576, total 0.4391
# Train accuracy: 99.14%
# Validation mAP (split 10/10) (2.5s): 74.43%
# --------------------------------------------------------------------------------
# Training... Epoch = 44
# Epoch 44, Batch 88/88 (19.6s): Center loss 0.2706, Softmax loss 0.1488, total 0.4211
# Train accuracy: 99.29%
# Validation mAP (split 10/10) (2.5s): 75.10%
# --------------------------------------------------------------------------------
# Training... Epoch = 45
# Epoch 45, Batch 88/88 (19.6s): Center loss 0.2759, Softmax loss 0.1539, total 0.4314
# Train accuracy: 99.19%
# Validation mAP (split 10/10) (2.5s): 75.93%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 75.62% | 75.93%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 46
# Epoch 46, Batch 88/88 (19.6s): Center loss 0.2735, Softmax loss 0.1466, total 0.4218
# Train accuracy: 99.32%
# Validation mAP (split 10/10) (2.6s): 71.99%
# --------------------------------------------------------------------------------
# Training... Epoch = 47
# Epoch 47, Batch 88/88 (19.7s): Center loss 0.2833, Softmax loss 0.1533, total 0.4384
# Train accuracy: 99.22%
# Validation mAP (split 10/10) (2.6s): 75.16%
# --------------------------------------------------------------------------------
# Training... Epoch = 48
# Epoch 48, Batch 88/88 (19.6s): Center loss 0.2807, Softmax loss 0.1498, total 0.4323
# Train accuracy: 99.35%
# Validation mAP (split 10/10) (2.6s): 74.44%
# --------------------------------------------------------------------------------
# Training... Epoch = 49
# Epoch 49, Batch 88/88 (19.7s): Center loss 0.2680, Softmax loss 0.1374, total 0.4072
# Train accuracy: 99.53%
# Validation mAP (split 10/10) (2.5s): 76.21%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 75.93% | 76.21%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 50
# Epoch 50, Batch 88/88 (19.6s): Center loss 0.2658, Softmax loss 0.1355, total 0.4032
# Train accuracy: 99.48%
# Validation mAP (split 10/10) (2.6s): 74.47%
# --------------------------------------------------------------------------------
# Training... Epoch = 51
# Epoch 51, Batch 88/88 (19.6s): Center loss 0.2768, Softmax loss 0.1420, total 0.4207
# Train accuracy: 99.30%
# Validation mAP (split 10/10) (2.4s): 75.96%
# --------------------------------------------------------------------------------
# Training... Epoch = 52
# Epoch 52, Batch 88/88 (19.9s): Center loss 0.2769, Softmax loss 0.1441, total 0.4230
# Train accuracy: 99.39%
# Validation mAP (split 10/10) (2.5s): 75.26%
# --------------------------------------------------------------------------------
# Training... Epoch = 53
# Epoch 53, Batch 88/88 (19.7s): Center loss 0.2723, Softmax loss 0.1391, total 0.4134
# Train accuracy: 99.36%
# Validation mAP (split 10/10) (2.5s): 75.40%
# --------------------------------------------------------------------------------
# Training... Epoch = 54
# Epoch 54, Batch 88/88 (19.7s): Center loss 0.2820, Softmax loss 0.1484, total 0.4323
# Train accuracy: 99.31%
# Validation mAP (split 10/10) (2.5s): 76.50%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 76.21% | 76.50%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 55
# Epoch 55, Batch 88/88 (19.6s): Center loss 0.2700, Softmax loss 0.1331, total 0.4052
# Train accuracy: 99.47%
# Validation mAP (split 10/10) (2.5s): 75.85%
# --------------------------------------------------------------------------------
# Training... Epoch = 56
# Epoch 56, Batch 88/88 (19.7s): Center loss 0.2654, Softmax loss 0.1304, total 0.3977
# Train accuracy: 99.52%
# Validation mAP (split 10/10) (2.4s): 76.81%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 76.50% | 76.81%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 57
# Epoch 57, Batch 88/88 (19.6s): Center loss 0.2666, Softmax loss 0.1293, total 0.3980
# Train accuracy: 99.46%
# Validation mAP (split 10/10) (2.4s): 75.14%
# --------------------------------------------------------------------------------
# Training... Epoch = 58
# Epoch 58, Batch 88/88 (19.6s): Center loss 0.2707, Softmax loss 0.1313, total 0.4041
# Train accuracy: 99.51%
# Validation mAP (split 10/10) (2.5s): 75.64%
# --------------------------------------------------------------------------------
# Training... Epoch = 59
# Epoch 59, Batch 88/88 (19.6s): Center loss 0.2727, Softmax loss 0.1315, total 0.4063
# Train accuracy: 99.46%
# Validation mAP (split 10/10) (2.4s): 73.95%
# --------------------------------------------------------------------------------
# Training... Epoch = 60
# Epoch 60, Batch 88/88 (19.6s): Center loss 0.2755, Softmax loss 0.1365, total 0.4141
# Train accuracy: 99.35%
# Validation mAP (split 10/10) (2.6s): 73.71%
# --------------------------------------------------------------------------------
# Training... Epoch = 61
# Epoch 61, Batch 88/88 (19.6s): Center loss 0.2792, Softmax loss 0.1389, total 0.4202
# Train accuracy: 99.25%
# Validation mAP (split 10/10) (2.5s): 75.38%
# --------------------------------------------------------------------------------
# Training... Epoch = 62
# Epoch 62, Batch 88/88 (19.6s): Center loss 0.2640, Softmax loss 0.1239, total 0.3900
# Train accuracy: 99.56%
# Validation mAP (split 10/10) (2.5s): 73.10%
# --------------------------------------------------------------------------------
# Training... Epoch = 63
# Epoch 63, Batch 88/88 (19.6s): Center loss 0.2695, Softmax loss 0.1281, total 0.3998
# Train accuracy: 99.46%
# Validation mAP (split 10/10) (2.5s): 73.33%
# --------------------------------------------------------------------------------
# Training... Epoch = 64
# Epoch 64, Batch 88/88 (19.7s): Center loss 0.2719, Softmax loss 0.1311, total 0.4051
# Train accuracy: 99.42%
# Validation mAP (split 10/10) (2.5s): 71.81%
# --------------------------------------------------------------------------------
# Training... Epoch = 65
# Epoch 65, Batch 88/88 (19.6s): Center loss 0.2717, Softmax loss 0.1276, total 0.4015
# Train accuracy: 99.53%
# Validation mAP (split 10/10) (2.4s): 76.58%
# --------------------------------------------------------------------------------
# Training... Epoch = 66
# Epoch 66, Batch 88/88 (19.6s): Center loss 0.2623, Softmax loss 0.1192, total 0.3837
# Train accuracy: 99.57%
# Validation mAP (split 10/10) (2.5s): 74.78%
# --------------------------------------------------------------------------------
# Training... Epoch = 67
# Epoch 67, Batch 88/88 (19.6s): Center loss 0.2702, Softmax loss 0.1270, total 0.3993
# Train accuracy: 99.56%
# Validation mAP (split 10/10) (2.7s): 73.61%
# --------------------------------------------------------------------------------
# Training... Epoch = 68
# Epoch 68, Batch 88/88 (19.6s): Center loss 0.2689, Softmax loss 0.1255, total 0.3966
# Train accuracy: 99.48%
# Validation mAP (split 10/10) (2.4s): 74.85%
# --------------------------------------------------------------------------------
# Training... Epoch = 69
# Epoch 69, Batch 88/88 (19.6s): Center loss 0.2742, Softmax loss 0.1304, total 0.4069
# Train accuracy: 99.32%
# Validation mAP (split 10/10) (2.4s): 76.40%
# --------------------------------------------------------------------------------
# Training... Epoch = 70
# Epoch 70, Batch 88/88 (19.6s): Center loss 0.2619, Softmax loss 0.1191, total 0.3833
# Train accuracy: 99.56%
# Validation mAP (split 10/10) (2.5s): 75.70%
# --------------------------------------------------------------------------------
# Training... Epoch = 71
# Epoch 71, Batch 88/88 (19.6s): Center loss 0.2607, Softmax loss 0.1188, total 0.3818
# Train accuracy: 99.54%
# Validation mAP (split 10/10) (2.5s): 75.34%
# --------------------------------------------------------------------------------
# Training... Epoch = 72
# Epoch 72, Batch 88/88 (19.6s): Center loss 0.2682, Softmax loss 0.1236, total 0.3940
# Train accuracy: 99.56%
# Validation mAP (split 10/10) (2.5s): 73.93%
# --------------------------------------------------------------------------------
# Training... Epoch = 73
# Epoch 73, Batch 88/88 (19.6s): Center loss 0.2717, Softmax loss 0.1267, total 0.4007
# Train accuracy: 99.44%
# Validation mAP (split 10/10) (2.5s): 74.59%
# --------------------------------------------------------------------------------
# Training... Epoch = 74
# Epoch 74, Batch 88/88 (19.6s): Center loss 0.2602, Softmax loss 0.1162, total 0.3787
# Train accuracy: 99.64%
# Validation mAP (split 10/10) (2.5s): 74.74%
# --------------------------------------------------------------------------------
# Training... Epoch = 75
# Epoch 75, Batch 88/88 (19.6s): Center loss 0.2667, Softmax loss 0.1236, total 0.3926
# Train accuracy: 99.46%
# Validation mAP (split 10/10) (2.5s): 74.57%
# --------------------------------------------------------------------------------
# Training... Epoch = 76
# Epoch 76, Batch 88/88 (19.6s): Center loss 0.2680, Softmax loss 0.1241, total 0.3943
# Train accuracy: 99.40%
# Validation mAP (split 10/10) (2.4s): 75.75%
# --------------------------------------------------------------------------------
# Training... Epoch = 77
# Epoch 77, Batch 88/88 (19.6s): Center loss 0.2570, Softmax loss 0.1126, total 0.3720
# Train accuracy: 99.49%
# Validation mAP (split 10/10) (2.4s): 75.93%
# --------------------------------------------------------------------------------
# Training... Epoch = 78
# Epoch 78, Batch 88/88 (19.6s): Center loss 0.2608, Softmax loss 0.1175, total 0.3807
# Train accuracy: 99.53%
# Validation mAP (split 10/10) (2.5s): 74.43%
# --------------------------------------------------------------------------------
# Training... Epoch = 79
# Epoch 79, Batch 88/88 (19.6s): Center loss 0.2665, Softmax loss 0.1221, total 0.3909
# Train accuracy: 99.47%
# Validation mAP (split 10/10) (2.5s): 71.99%
# --------------------------------------------------------------------------------
# Training... Epoch = 80
# Epoch 80, Batch 88/88 (19.6s): Center loss 0.2635, Softmax loss 0.1195, total 0.3853
# Train accuracy: 99.48%
# Validation mAP (split 10/10) (2.4s): 75.12%
# --------------------------------------------------------------------------------
# Training... Epoch = 81
# Epoch 81, Batch 88/88 (19.6s): Center loss 0.2595, Softmax loss 0.1122, total 0.3740
# Train accuracy: 99.68%
# Validation mAP (split 10/10) (2.5s): 74.70%
# --------------------------------------------------------------------------------
# Training... Epoch = 82
# Epoch 82, Batch 88/88 (19.6s): Center loss 0.2574, Softmax loss 0.1130, total 0.3728
# Train accuracy: 99.56%
# Validation mAP (split 10/10) (2.5s): 74.31%
# --------------------------------------------------------------------------------
# Training... Epoch = 83
# Epoch 83, Batch 88/88 (19.7s): Center loss 0.2619, Softmax loss 0.1164, total 0.3807
# Train accuracy: 99.52%
# Validation mAP (split 10/10) (2.4s): 74.43%
# --------------------------------------------------------------------------------
# Training... Epoch = 84
# Epoch 84, Batch 88/88 (19.6s): Center loss 0.2675, Softmax loss 0.1208, total 0.3906
# Train accuracy: 99.53%
# Validation mAP (split 10/10) (2.4s): 75.52%
# --------------------------------------------------------------------------------
# Training... Epoch = 85
# Epoch 85, Batch 88/88 (19.6s): Center loss 0.2606, Softmax loss 0.1139, total 0.3769
# Train accuracy: 99.62%
# Validation mAP (split 10/10) (2.5s): 74.52%
# --------------------------------------------------------------------------------
# Training... Epoch = 86
# Epoch 86, Batch 88/88 (19.6s): Center loss 0.2542, Softmax loss 0.1081, total 0.3647
# Train accuracy: 99.65%
# Validation mAP (split 10/10) (2.4s): 76.20%
# --------------------------------------------------------------------------------
# Training... Epoch = 87
# Epoch 87, Batch 88/88 (19.6s): Center loss 0.2623, Softmax loss 0.1162, total 0.3808
# Train accuracy: 99.57%
# Validation mAP (split 10/10) (2.5s): 74.47%
# --------------------------------------------------------------------------------
# Training... Epoch = 88
# Epoch 88, Batch 88/88 (19.6s): Center loss 0.2637, Softmax loss 0.1166, total 0.3827
# Train accuracy: 99.58%
# Validation mAP (split 10/10) (2.5s): 73.19%
# --------------------------------------------------------------------------------
# Training... Epoch = 89
# Epoch 89, Batch 88/88 (19.6s): Center loss 0.2549, Softmax loss 0.1104, total 0.3677
# Train accuracy: 99.60%
# Validation mAP (split 10/10) (2.5s): 74.55%
# --------------------------------------------------------------------------------
# Training... Epoch = 90
# Epoch 90, Batch 88/88 (19.6s): Center loss 0.2544, Softmax loss 0.1074, total 0.3642
# Train accuracy: 99.73%
# Validation mAP (split 10/10) (2.5s): 75.08%
# --------------------------------------------------------------------------------
# Training... Epoch = 91
# Epoch 91, Batch 88/88 (20.2s): Center loss 0.2559, Softmax loss 0.1100, total 0.3683
# Train accuracy: 99.64%
# Validation mAP (split 10/10) (3.1s): 73.17%
# --------------------------------------------------------------------------------
# Training... Epoch = 92
# Epoch 92, Batch 88/88 (20.4s): Center loss 0.2579, Softmax loss 0.1113, total 0.3715
# Train accuracy: 99.65%
# Validation mAP (split 10/10) (2.8s): 73.92%
# --------------------------------------------------------------------------------
# Epoch    91: reducing learning rate of group 0 to 1.0000e-04.
# Training... Epoch = 93
# Epoch 93, Batch 88/88 (20.8s): Center loss 0.2135, Softmax loss 0.0728, total 0.2888
# Train accuracy: 99.80%
# Validation mAP (split 10/10) (2.4s): 78.74%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 76.81% | 78.74%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 94
# Epoch 94, Batch 88/88 (19.8s): Center loss 0.1876, Softmax loss 0.0571, total 0.2473
# Train accuracy: 99.99%
# Validation mAP (split 10/10) (2.3s): 79.41%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 78.74% | 79.41%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 95
# Epoch 95, Batch 88/88 (19.7s): Center loss 0.1777, Softmax loss 0.0538, total 0.2340
# Train accuracy: 99.99%
# Validation mAP (split 10/10) (2.4s): 79.18%
# --------------------------------------------------------------------------------
# Training... Epoch = 96
# Epoch 96, Batch 88/88 (19.7s): Center loss 0.1729, Softmax loss 0.0523, total 0.2277
# Train accuracy: 99.98%
# Validation mAP (split 10/10) (2.3s): 79.06%
# --------------------------------------------------------------------------------
# Training... Epoch = 97
# Epoch 97, Batch 88/88 (19.8s): Center loss 0.1672, Softmax loss 0.0507, total 0.2203
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.4s): 79.18%
# --------------------------------------------------------------------------------
# Training... Epoch = 98
# Epoch 98, Batch 88/88 (19.7s): Center loss 0.1655, Softmax loss 0.0511, total 0.2190
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.3s): 79.01%
# --------------------------------------------------------------------------------
# Training... Epoch = 99
# Epoch 99, Batch 88/88 (19.7s): Center loss 0.1635, Softmax loss 0.0513, total 0.2172
# Train accuracy: 99.99%
# Validation mAP (split 10/10) (2.3s): 79.20%
# --------------------------------------------------------------------------------
# Training... Epoch = 100
# Epoch 100, Batch 88/88 (19.7s): Center loss 0.1595, Softmax loss 0.0503, total 0.2122
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.4s): 78.99%
# --------------------------------------------------------------------------------
# Training... Epoch = 101
# Epoch 101, Batch 88/88 (19.8s): Center loss 0.1584, Softmax loss 0.0488, total 0.2096
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.4s): 79.14%
# --------------------------------------------------------------------------------
# Training... Epoch = 102
# Epoch 102, Batch 88/88 (19.8s): Center loss 0.1561, Softmax loss 0.0490, total 0.2074
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.3s): 78.78%
# --------------------------------------------------------------------------------
# Training... Epoch = 103
# Epoch 103, Batch 88/88 (19.7s): Center loss 0.1562, Softmax loss 0.0486, total 0.2071
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.3s): 78.60%
# --------------------------------------------------------------------------------
# Training... Epoch = 104
# Epoch 104, Batch 88/88 (19.7s): Center loss 0.1547, Softmax loss 0.0488, total 0.2058
# Train accuracy: 99.99%
# Validation mAP (split 10/10) (2.4s): 78.83%
# --------------------------------------------------------------------------------
# Training... Epoch = 105
# Epoch 105, Batch 88/88 (19.7s): Center loss 0.1535, Softmax loss 0.0482, total 0.2041
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.4s): 78.72%
# --------------------------------------------------------------------------------
# Training... Epoch = 106
# Epoch 106, Batch 88/88 (19.7s): Center loss 0.1542, Softmax loss 0.0484, total 0.2050
# Train accuracy: 99.99%
# Validation mAP (split 10/10) (2.4s): 78.56%
# --------------------------------------------------------------------------------
# Training... Epoch = 107
# Epoch 107, Batch 88/88 (19.7s): Center loss 0.1543, Softmax loss 0.0484, total 0.2050
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.4s): 78.61%
# --------------------------------------------------------------------------------
# Training... Epoch = 108
# Epoch 108, Batch 88/88 (19.7s): Center loss 0.1544, Softmax loss 0.0484, total 0.2051
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.4s): 78.51%
# --------------------------------------------------------------------------------
# Training... Epoch = 109
# Epoch 109, Batch 88/88 (19.8s): Center loss 0.1537, Softmax loss 0.0484, total 0.2044
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.4s): 78.36%
# --------------------------------------------------------------------------------
# Training... Epoch = 110
# Epoch 110, Batch 88/88 (19.8s): Center loss 0.1522, Softmax loss 0.0474, total 0.2020
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.4s): 78.26%
# --------------------------------------------------------------------------------
# Training... Epoch = 111
# Epoch 111, Batch 88/88 (19.7s): Center loss 0.1515, Softmax loss 0.0475, total 0.2013
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.4s): 78.06%
# --------------------------------------------------------------------------------
# Training... Epoch = 112
# Epoch 112, Batch 88/88 (19.7s): Center loss 0.1512, Softmax loss 0.0471, total 0.2007
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.4s): 77.67%
# --------------------------------------------------------------------------------
# Training... Epoch = 113
# Epoch 113, Batch 88/88 (19.7s): Center loss 0.1513, Softmax loss 0.0471, total 0.2007
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.3s): 77.77%
# --------------------------------------------------------------------------------
# Training... Epoch = 114
# Epoch 114, Batch 88/88 (19.6s): Center loss 0.1506, Softmax loss 0.0467, total 0.1996
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.3s): 77.71%
# --------------------------------------------------------------------------------
# Training... Epoch = 115
# Epoch 115, Batch 88/88 (19.6s): Center loss 0.1525, Softmax loss 0.0475, total 0.2023
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.3s): 77.78%
# --------------------------------------------------------------------------------
# Training... Epoch = 116
# Epoch 116, Batch 88/88 (19.6s): Center loss 0.1515, Softmax loss 0.0470, total 0.2009
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.4s): 77.58%
# --------------------------------------------------------------------------------
# Training... Epoch = 117
# Epoch 117, Batch 88/88 (19.6s): Center loss 0.1523, Softmax loss 0.0468, total 0.2015
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.4s): 77.91%
# --------------------------------------------------------------------------------
# Training... Epoch = 118
# Epoch 118, Batch 88/88 (19.6s): Center loss 0.1515, Softmax loss 0.0469, total 0.2008
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.4s): 77.76%
# --------------------------------------------------------------------------------
# Training... Epoch = 119
# Epoch 119, Batch 88/88 (19.6s): Center loss 0.1512, Softmax loss 0.0469, total 0.2004
# Train accuracy: 99.99%
# Validation mAP (split 10/10) (2.4s): 77.64%
# --------------------------------------------------------------------------------
# Training... Epoch = 120
# Epoch 120, Batch 88/88 (19.6s): Center loss 0.1508, Softmax loss 0.0466, total 0.1998
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.5s): 77.70%
# --------------------------------------------------------------------------------
# Training... Epoch = 121
# Epoch 121, Batch 88/88 (19.6s): Center loss 0.1514, Softmax loss 0.0464, total 0.2002
# Train accuracy: 99.99%
# Validation mAP (split 10/10) (2.4s): 77.56%
# --------------------------------------------------------------------------------
# Training... Epoch = 122
# Epoch 122, Batch 88/88 (19.6s): Center loss 0.1511, Softmax loss 0.0462, total 0.1996
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.4s): 77.82%
# --------------------------------------------------------------------------------
# Training... Epoch = 123
# Epoch 123, Batch 88/88 (19.6s): Center loss 0.1509, Softmax loss 0.0461, total 0.1994
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.3s): 77.33%
# --------------------------------------------------------------------------------
# Training... Epoch = 124
# Epoch 124, Batch 88/88 (19.6s): Center loss 0.1508, Softmax loss 0.0457, total 0.1989
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.4s): 77.36%
# --------------------------------------------------------------------------------
# Training... Epoch = 125
# Epoch 125, Batch 88/88 (19.6s): Center loss 0.1520, Softmax loss 0.0464, total 0.2007
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.4s): 76.82%
# --------------------------------------------------------------------------------
# Training... Epoch = 126
# Epoch 126, Batch 88/88 (19.6s): Center loss 0.1527, Softmax loss 0.0464, total 0.2015
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.4s): 77.05%
# --------------------------------------------------------------------------------
# Training... Epoch = 127
# Epoch 127, Batch 88/88 (19.6s): Center loss 0.1508, Softmax loss 0.0459, total 0.1991
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.8s): 77.14%
# --------------------------------------------------------------------------------
# Training... Epoch = 128
# Epoch 128, Batch 88/88 (19.6s): Center loss 0.1512, Softmax loss 0.0457, total 0.1993
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.7s): 77.29%
# --------------------------------------------------------------------------------
# Training... Epoch = 129
# Epoch 129, Batch 88/88 (19.6s): Center loss 0.1506, Softmax loss 0.0455, total 0.1985
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.8s): 76.53%
# --------------------------------------------------------------------------------
# Training... Epoch = 130
# Epoch 130, Batch 88/88 (19.6s): Center loss 0.1523, Softmax loss 0.0455, total 0.2002
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.7s): 76.90%
# --------------------------------------------------------------------------------
# Epoch   129: reducing learning rate of group 0 to 1.0000e-05.
# Training... Epoch = 131
# Epoch 131, Batch 88/88 (19.6s): Center loss 0.1447, Softmax loss 0.0425, total 0.1896
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.8s): 77.09%
# --------------------------------------------------------------------------------
# Training... Epoch = 132
# Epoch 132, Batch 88/88 (19.6s): Center loss 0.1422, Softmax loss 0.0415, total 0.1861
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.8s): 76.94%
# --------------------------------------------------------------------------------
# Training... Epoch = 133
# Epoch 133, Batch 88/88 (19.6s): Center loss 0.1403, Softmax loss 0.0409, total 0.1837
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.8s): 76.96%
# --------------------------------------------------------------------------------
# Training... Epoch = 134
# Epoch 134, Batch 88/88 (19.7s): Center loss 0.1401, Softmax loss 0.0408, total 0.1833
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.8s): 77.06%
# --------------------------------------------------------------------------------
# Training... Epoch = 135
# Epoch 135, Batch 88/88 (19.6s): Center loss 0.1397, Softmax loss 0.0404, total 0.1826
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.7s): 76.93%
# --------------------------------------------------------------------------------
# Training... Epoch = 136
# Epoch 136, Batch 88/88 (19.6s): Center loss 0.1384, Softmax loss 0.0402, total 0.1810
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.8s): 77.05%
# --------------------------------------------------------------------------------
# Training... Epoch = 137
# Epoch 137, Batch 88/88 (19.6s): Center loss 0.1386, Softmax loss 0.0403, total 0.1813
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.7s): 76.97%
# --------------------------------------------------------------------------------
# Training... Epoch = 138
# Epoch 138, Batch 88/88 (19.6s): Center loss 0.1375, Softmax loss 0.0400, total 0.1798
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.7s): 76.88%
# --------------------------------------------------------------------------------
# Training... Epoch = 139
# Epoch 139, Batch 88/88 (19.6s): Center loss 0.1371, Softmax loss 0.0402, total 0.1797
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.8s): 77.08%
# --------------------------------------------------------------------------------
# Training... Epoch = 140
# Epoch 140, Batch 88/88 (19.6s): Center loss 0.1375, Softmax loss 0.0398, total 0.1797
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.8s): 77.06%
# --------------------------------------------------------------------------------
# Training... Epoch = 141
# Epoch 141, Batch 88/88 (19.6s): Center loss 0.1357, Softmax loss 0.0397, total 0.1777
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.7s): 77.04%
# --------------------------------------------------------------------------------
# Training... Epoch = 142
# Epoch 142, Batch 88/88 (19.6s): Center loss 0.1360, Softmax loss 0.0398, total 0.1782
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.8s): 76.98%
# --------------------------------------------------------------------------------
# Training... Epoch = 143
# Epoch 143, Batch 88/88 (19.6s): Center loss 0.1349, Softmax loss 0.0398, total 0.1771
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.8s): 76.88%
# --------------------------------------------------------------------------------
# Training... Epoch = 144
# Epoch 144, Batch 88/88 (19.6s): Center loss 0.1372, Softmax loss 0.0402, total 0.1798
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.7s): 76.85%
# --------------------------------------------------------------------------------
# Training... Epoch = 145
# Epoch 145, Batch 88/88 (19.7s): Center loss 0.1362, Softmax loss 0.0395, total 0.1781
# Train accuracy: 100.00%
# Validation mAP (split 10/10) (2.7s): 76.91%
# --------------------------------------------------------------------------------
# Early stopping at epoch 145.
