# %% [markdown]
# # Treinamento do modelo para Transfer Learning usando Market-1501 e CUHK03

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
import torch
import torch as tc
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from  torch.utils.data import DataLoader
import torch.optim.lr_scheduler as lr_scheduler
import matplotlib.pyplot as plt
# %matplotlib inline
import torchvision.datasets as dset
import numpy as np
import cv2

from center_loss import CenterLoss
from frw import L2_penalty_with_constant
from reid_model import ReID_Net
from datasets import Market1501, CUHK03, ConcatenateDataset
from custom_transforms import RandomTranslation
from evaluation import pairwise_squared_euclidian_distance, generate_query, \
                        get_topk_results, apk, mapk, calculate_mAP
from utils import MetricAverager, save_checkpoint, load_checkpoint
import time
import shutil

# %% [markdown]
# ## Dataset, transformações de _data augmentation_ e DataLoaders

# %%
data_transforms = {
    'train': transforms.Compose([
        RandomTranslation(0.1),   # translação em numpy array
        transforms.ToPILImage(),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),    # range [0.0, 1.0]
        transforms.Lambda(lambda t: t/0.5 - 1)    # range [-1.0, 1.0]
    ]),
    'valid': transforms.Compose([
        transforms.ToTensor(),
        transforms.Lambda(lambda t: t/0.5 - 1)
    ])
}

# %%
individual_datasets = {
    'market': {
        'train': Market1501('../reid/datasets/market_train_correct.npz', 
                            transform=data_transforms['train']),
        'valid': Market1501('../reid/datasets/market_train_correct.npz', train=False, 
                            transform=data_transforms['valid'])
    },
    'cuhk03': {
        'train': CUHK03('../reid/datasets/cuhk03_train_correct.npz', 
                        transform=data_transforms['train']),
        'valid': CUHK03('../reid/datasets/cuhk03_train_correct.npz', train=False, 
                        transform=data_transforms['valid'])
    }   
}

# market = individual_datasets['market']
# market['train'].X = market['train'].X[:3000]
# market['train'].y = market['train'].y[:3000]

# cuhk03 = individual_datasets['cuhk03']
# cuhk03['train'].X = cuhk03['train'].X[:3000]
# cuhk03['train'].y = cuhk03['train'].y[:3000]


datasets = {
    'train': ConcatenateDataset(individual_datasets['market']['train'], individual_datasets['cuhk03']['train']),
    'valid': ConcatenateDataset(individual_datasets['market']['valid'], individual_datasets['cuhk03']['valid']),
}

batch_size = 128
dset_loaders = {
    'train': DataLoader(datasets['train'], batch_size=batch_size, shuffle=True, num_workers=4),
    'valid': DataLoader(datasets['valid'], batch_size=batch_size, shuffle=False, num_workers=4)
}

# %%
market = individual_datasets['market']
print('Market1501:')
print('Treinamento:')
print('X:', market['train'].X.shape, market['train'].X.dtype, market['train'].X.min(), market['train'].X.max())
print('y:', market['train'].y.shape, market['train'].y.dtype, market['train'].y.min(), market['train'].y.max())
print('Validação:')
print('X:', market['valid'].X.shape, market['valid'].X.dtype, market['valid'].X.min(), market['valid'].X.max())
print('y:', market['valid'].y.shape, market['valid'].y.dtype, market['valid'].y.min(), market['valid'].y.max())

cuhk03 = individual_datasets['cuhk03']
print('\nCUHK03:')
print('Treinamento:')
print('X:', cuhk03['train'].X.shape, cuhk03['train'].X.dtype, cuhk03['train'].X.min(), cuhk03['train'].X.max())
print('y:', cuhk03['train'].y.shape, cuhk03['train'].y.dtype, cuhk03['train'].y.min(), cuhk03['train'].y.max())
print('Validação:')
print('X:', cuhk03['valid'].X.shape, cuhk03['valid'].X.dtype, cuhk03['valid'].X.min(), cuhk03['valid'].X.max())
print('y:', cuhk03['valid'].y.shape, cuhk03['valid'].y.dtype, cuhk03['valid'].y.min(), cuhk03['valid'].y.max())

print()
print('Tamanho dataset concatenado: ')
print('Treinamento:')
print('X:', datasets['train'].X.shape, datasets['train'].X.dtype, datasets['train'].X.min(), datasets['train'].X.max())
print('y:', datasets['train'].y.shape, datasets['train'].y.dtype, datasets['train'].y.min(), datasets['train'].y.max())
print('Validação:')
print('X:', datasets['valid'].X.shape, datasets['valid'].X.dtype, datasets['valid'].X.min(), datasets['valid'].X.max())
print('y:', datasets['valid'].y.shape, datasets['valid'].y.dtype, datasets['valid'].y.min(), datasets['valid'].y.max())
# Out:
# Market1501:
# Treinamento:
# X: (11253, 128, 48, 3) uint8 0 255
# y: (11253,) int64 0 650
# Validação:
# X: (1683, 128, 48, 3) uint8 0 255
# y: (1683,) int64 0 99
#
# CUHK03:
# Treinamento:
# X: (12165, 128, 48, 3) uint8 0 255
# y: (12165,) int64 0 1266
# Validação:
# X: (966, 128, 48, 3) uint8 0 255
# y: (966,) int64 0 99
#
# Tamanho dataset concatenado:
# Treinamento:
# X: (23418, 128, 48, 3) uint8 0 255
# y: (23418,) int64 0 1917
# Validação:
# X: (2649, 128, 48, 3) uint8 0 255
# y: (2649,) int64 0 199

# %%
datasets['train'].num_classes, datasets['valid'].num_classes
# Out:
# (1918, 200)

# %%
len(dset_loaders['train']), len(dset_loaders['valid'])
# Out:
# (183, 21)

# %% [markdown]
# ## Funções de treinamento
#
# ### Para uma época

# %%
def train_epoch(model, optimizer, epoch, criterions, train_loader, val_loader, use_cuda,
                lambda_cl, beta_frw, query_splits, cuda_device=None):
    print("Training... Epoch = %d" % epoch)

    train_accum = 0
    n_train_samples = 0
    val_accum = 0
    n_val_samples = 0
    
    tlosses = {
        'center_loss': MetricAverager(),
        'softmax_loss': MetricAverager(),
        'total': MetricAverager(),
    }
    
    #train
    model.train(True)
    t0 = time.time()
    for i,(data, target) in enumerate(train_loader):
        
        if use_cuda:
            data = data.cuda()
            target = target.cuda()
        data, target = Variable(data), Variable(target)
        
        
        features, pred = model(data)
        
        # Softmax loss + center loss
        softmax_loss = criterions[0](pred, target)
        center_loss = lambda_cl * criterions[1](features, target)
        loss = softmax_loss + center_loss
        
        # Acrescenta a penalização L2 na camada FRW
        for (name, p) in model.named_parameters():
            if name == 'frw.weight' or name == 'fc_embeddings.3.weight':
                loss += beta_frw * criterions[2](p)
        
        _, preds = torch.max(pred.data, 1)
        correct = (preds == target.data).sum()
        train_accum += correct
        n_train_samples += target.size(0)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        tlosses['center_loss'].update(center_loss.data.cpu().numpy()[0])
        tlosses['softmax_loss'].update(softmax_loss.data.cpu().numpy()[0])
        tlosses['total'].update(loss.data.cpu().numpy()[0])
        
        t1 = time.time() - t0
        train_string = 'Epoch {}, Batch {}/{} ({:.1f}s): Center loss {:.4f}, Softmax loss {:.4f}, ' \
            'total {:.4f}'.format(epoch, i+1, len(train_loader), t1, tlosses['center_loss'], 
                                  tlosses['softmax_loss'], tlosses['total'])
        print(train_string, end='\r' if i < len(train_loader)-1 else '\n')
    
    train_acc = train_accum / n_train_samples
    print('Train accuracy: {:.2%}'.format(train_acc))
        
    # Validation: in the validation phase, we extract the features of all the validation images.
    # Then, we calculate the pairwise euclidian distance for all samples and calculate
    # the Mean Average Precision for the rankings in a Cross-camera search configuration: the query and
    # gallery sets have images from different camera views and, for each person identity, one image 
    # is randomly selected for each set. This is done for N query/gallery split configurations.
    
    t0 = time.time()
    model.train(False)
    
    val_feats = []
    val_pids = []
    
    valid_metrics = {
        'map': MetricAverager(),
    }
    
    for i, (data, target) in enumerate(val_loader):
        
        if use_cuda:
            data = data.cuda()
        data = Variable(data, volatile=True)

        features, pred = model(data)
        val_feats.append(features.data.cpu())
        
    val_feats = torch.cat(val_feats)
    
    # Calculates mAP for the validation set, as if it was a Query-Gallery set
    val_dataset = val_loader.dataset
    val_cam_ids = val_dataset.cam_ids
    y_val = val_dataset.y
    
    # Gallery: may or may not include distractors
    y_gallery = y_val
    gal_cam_ids = val_cam_ids
    
    for i, query_indices_by_cam in enumerate(query_splits):
        #query_indices_by_cam = generate_query(y_val, val_cam_ids)
        val_map = calculate_mAP(query_indices_by_cam, val_feats, y_gallery, gal_cam_ids)
        valid_metrics['map'].update(val_map)

        t1 = time.time() - t0
        print('Validation mAP (split {:>2}/{}) ({:.1f}s): {:.2%}'.format(i+1, len(query_splits),
                t1, valid_metrics['map'].mean), end='\r' if i+1 < len(query_splits) else '\n')
        
    print('-'*80)
        
    
    metrics = {
        'train': {
            'losses': {
                'center_loss': tlosses['center_loss'].mean,
                'softmax_loss': tlosses['softmax_loss'].mean,
                'total': tlosses['total'].mean,
            },
            'accuracy': train_acc,
        },
        'valid': {
            'map': valid_metrics['map'].mean
        }
    }
    
    return metrics

# %% [markdown]
# ### Para o treinamento completo

# %%
def train(epochs, model=None, resume=None, checkpoint_fn=None, **train_args):
    best_val_loss = None
    last_epoch = 0
    
    train_history = []
    
    use_cuda = train_args.get('use_cuda')
    
    if model is None:
        num_classes = train_args.pop('num_classes')
        model = ReID_Net(num_classes)
    
    if resume is not None:
        scheduler, last_epoch, best_val_loss, train_history = load_checkpoint(resume, model, optimizer4nn)
        num_classes = model.centers.size(0)
    
    # NLLLoss
    nllloss = nn.NLLLoss() #CrossEntropyLoss = log_softmax + NLLLoss
    # CenterLoss
    loss_weight = 1.0

    # FRW L2 penalty
    frw_l2_penalty = L2_penalty_with_constant(200)
    
    if use_cuda:
        nllloss = nllloss.cuda()
        model = model.cuda()
        frw_l2_penalty = frw_l2_penalty.cuda()
        
    
    alpha = train_args.pop('alpha')

    centerloss = CenterLoss(model, model.centers, num_classes, alpha)
    criterions = [nllloss, centerloss, frw_l2_penalty]

    # optimzer4nn
    lr = train_args.pop('lr')
    weight_decay = train_args.pop('weight_decay')
    optimizer4nn = optim.Adam(model.parameters(),lr=lr, weight_decay=weight_decay)
    
    # LR Scheduler
    scheduler_patience = train_args.pop('scheduler_patience', 35)
    scheduler_factor = train_args.pop('scheduler_factor', 0.1)
    scheduler = lr_scheduler.ReduceLROnPlateau(optimizer4nn, mode='max',
                                               patience=scheduler_patience, 
                                               factor=scheduler_factor, verbose=True)
        
    max_val_map = best_val_loss or -np.Inf
    
    patience = train_args.pop('patience', 50)
    no_improve = 0
    
    print('train_args:', train_args, '\n')
    
    # Gera os splits de query e gallery que serão usados nas métricas de validação
    val_dataset = train_args['val_loader'].dataset
    query_splits = []
    for i in range(5):
        query_splits.append(generate_query(val_dataset.y, val_dataset.cam_ids))
    
    for epoch in range(last_epoch+1, epochs):

        metrics = train_epoch(model, optimizer4nn, epoch, criterions,
                              query_splits=query_splits, **train_args)
        
        scheduler.step(metrics['valid']['map'])
        train_history.append(metrics)
        
        # Save checkpoint and EarlyStop
        if metrics['valid']['map'] > max_val_map:
            print("Max. Valid. mAP / Epoch's Valid. mAP: {:.2%} | {:.2%}".format(
                max_val_map, metrics['valid']['map']))
            print('Salvando melhor modelo...')
            max_val_map = metrics['valid']['map']
            state = {
                'epoch': epoch,
                'state_dict': model.state_dict(),
                'best_val_loss': max_val_map,
                'train_softmax_loss': metrics['train']['losses']['softmax_loss'],
                'history': train_history,
            }
            opts = {'is_best': False}
            if checkpoint_fn is not None:
                opts.update({'filename': checkpoint_fn.format(epoch+1)})
            save_checkpoint(state, **opts)
            no_improve = 0
            print('-'*80)
        else:
            no_improve += 1
            if no_improve > patience:
                print('Early stopping at epoch {}.'.format(epoch))
                break
                
    return model, train_history

# %% [markdown]
# ## Parâmetros de treinamento e treino

# %%
epochs = 500

train_params = {
    'lr': 0.001,
    'weight_decay': 0.001,
    'lambda_cl': 0.01,
    'alpha': 0.5,
    'num_classes': len(np.unique(datasets['train'].y)),
    'train_loader': dset_loaders['train'],
    'val_loader': dset_loaders['valid'],
    'use_cuda': True,
    'beta_frw': 0.0001,
    'cuda_device': None,
    'patience': 55,
    'scheduler_patience': 40,
    'scheduler_factor': 0.1
}

# %%
try:
    model, train_history = train(epochs, model=None, 
                                 checkpoint_fn='market1501_and_cuhk03_map_epoch_{}.pth', 
                                 **train_params)
    
except KeyboardInterrupt:
    print('Interrompendo...')
# Out:
# train_args: {'val_loader': <torch.utils.data.dataloader.DataLoader object at 0x7fcf98d86668>, 'lambda_cl': 0.01, 'cuda_device': None, 'train_loader': <torch.utils.data.dataloader.DataLoader object at 0x7fcf98d861d0>, 'beta_frw': 0.0001, 'use_cuda': True}
#
# Training... Epoch = 1
# Epoch 1, Batch 183/183 (40.6s): Center loss 0.6226, Softmax loss 6.6646, total 7.3641
# Train accuracy: 2.66%
# Validation mAP (split  5/5) (3.6s): 30.69%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: -inf% | 30.69%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 2
# Epoch 2, Batch 183/183 (40.7s): Center loss 0.1829, Softmax loss 5.1115, total 5.2953
# Train accuracy: 11.72%
# Validation mAP (split  5/5) (3.4s): 41.85%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 30.69% | 41.85%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 3
# Epoch 3, Batch 183/183 (40.6s): Center loss 0.3189, Softmax loss 3.7051, total 4.0248
# Train accuracy: 26.86%
# Validation mAP (split  5/5) (3.0s): 48.98%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 41.85% | 48.98%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 4
# Epoch 4, Batch 183/183 (41.0s): Center loss 0.4547, Softmax loss 2.5376, total 2.9927
# Train accuracy: 46.46%
# Validation mAP (split  5/5) (3.1s): 53.25%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 48.98% | 53.25%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 5
# Epoch 5, Batch 183/183 (40.8s): Center loss 0.5395, Softmax loss 1.7549, total 2.2945
# Train accuracy: 62.94%
# Validation mAP (split  5/5) (3.0s): 58.11%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 53.25% | 58.11%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 6
# Epoch 6, Batch 183/183 (40.7s): Center loss 0.5747, Softmax loss 1.2934, total 1.8682
# Train accuracy: 74.34%
# Validation mAP (split  5/5) (2.8s): 60.63%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 58.11% | 60.63%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 7
# Epoch 7, Batch 183/183 (40.8s): Center loss 0.5828, Softmax loss 1.0365, total 1.6195
# Train accuracy: 81.25%
# Validation mAP (split  5/5) (2.8s): 60.87%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 60.63% | 60.87%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 8
# Epoch 8, Batch 183/183 (40.7s): Center loss 0.5848, Softmax loss 0.8887, total 1.4738
# Train accuracy: 84.91%
# Validation mAP (split  5/5) (2.7s): 65.88%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 60.87% | 65.88%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 9
# Epoch 9, Batch 183/183 (40.9s): Center loss 0.5851, Softmax loss 0.7862, total 1.3716
# Train accuracy: 87.48%
# Validation mAP (split  5/5) (2.7s): 67.05%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 65.88% | 67.05%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 10
# Epoch 10, Batch 183/183 (40.9s): Center loss 0.5805, Softmax loss 0.7122, total 1.2932
# Train accuracy: 89.24%
# Validation mAP (split  5/5) (2.7s): 66.96%
# --------------------------------------------------------------------------------
# Training... Epoch = 11
# Epoch 11, Batch 183/183 (40.9s): Center loss 0.5794, Softmax loss 0.6571, total 1.2370
# Train accuracy: 90.88%
# Validation mAP (split  5/5) (2.7s): 70.37%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 67.05% | 70.37%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 12
# Epoch 12, Batch 183/183 (41.0s): Center loss 0.5816, Softmax loss 0.6182, total 1.2005
# Train accuracy: 91.91%
# Validation mAP (split  5/5) (2.9s): 67.76%
# --------------------------------------------------------------------------------
# Training... Epoch = 13
# Epoch 13, Batch 183/183 (41.1s): Center loss 0.5816, Softmax loss 0.5873, total 1.1695
# Train accuracy: 92.63%
# Validation mAP (split  5/5) (2.7s): 70.13%
# --------------------------------------------------------------------------------
# Training... Epoch = 14
# Epoch 14, Batch 183/183 (41.1s): Center loss 0.5804, Softmax loss 0.5648, total 1.1460
# Train accuracy: 92.98%
# Validation mAP (split  5/5) (2.6s): 70.01%
# --------------------------------------------------------------------------------
# Training... Epoch = 15
# Epoch 15, Batch 183/183 (41.0s): Center loss 0.5780, Softmax loss 0.5420, total 1.1207
# Train accuracy: 93.55%
# Validation mAP (split  5/5) (2.6s): 71.73%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 70.37% | 71.73%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 16
# Epoch 16, Batch 183/183 (41.6s): Center loss 0.5779, Softmax loss 0.5154, total 1.0942
# Train accuracy: 94.12%
# Validation mAP (split  5/5) (2.7s): 70.62%
# --------------------------------------------------------------------------------
# Training... Epoch = 17
# Epoch 17, Batch 183/183 (40.6s): Center loss 0.5805, Softmax loss 0.5003, total 1.0817
# Train accuracy: 94.45%
# Validation mAP (split  5/5) (2.8s): 71.81%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 71.73% | 71.81%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 18
# Epoch 18, Batch 183/183 (40.7s): Center loss 0.5760, Softmax loss 0.4796, total 1.0567
# Train accuracy: 94.79%
# Validation mAP (split  5/5) (2.6s): 71.21%
# --------------------------------------------------------------------------------
# Training... Epoch = 19
# Epoch 19, Batch 183/183 (41.2s): Center loss 0.5766, Softmax loss 0.4699, total 1.0476
# Train accuracy: 95.04%
# Validation mAP (split  5/5) (2.5s): 74.09%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 71.81% | 74.09%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 20
# Epoch 20, Batch 183/183 (40.7s): Center loss 0.5779, Softmax loss 0.4633, total 1.0423
# Train accuracy: 95.18%
# Validation mAP (split  5/5) (2.5s): 72.96%
# --------------------------------------------------------------------------------
# Training... Epoch = 21
# Epoch 21, Batch 183/183 (40.8s): Center loss 0.5794, Softmax loss 0.4517, total 1.0324
# Train accuracy: 95.47%
# Validation mAP (split  5/5) (2.5s): 75.41%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 74.09% | 75.41%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 22
# Epoch 22, Batch 183/183 (40.5s): Center loss 0.5718, Softmax loss 0.4296, total 1.0029
# Train accuracy: 96.08%
# Validation mAP (split  5/5) (2.7s): 73.77%
# --------------------------------------------------------------------------------
# Training... Epoch = 23
# Epoch 23, Batch 183/183 (40.6s): Center loss 0.5787, Softmax loss 0.4298, total 1.0099
# Train accuracy: 95.74%
# Validation mAP (split  5/5) (2.6s): 74.95%
# --------------------------------------------------------------------------------
# Training... Epoch = 24
# Epoch 24, Batch 183/183 (41.1s): Center loss 0.5772, Softmax loss 0.4169, total 0.9956
# Train accuracy: 96.08%
# Validation mAP (split  5/5) (2.5s): 75.01%
# --------------------------------------------------------------------------------
# Training... Epoch = 25
# Epoch 25, Batch 183/183 (41.0s): Center loss 0.5738, Softmax loss 0.4122, total 0.9876
# Train accuracy: 96.18%
# Validation mAP (split  5/5) (2.9s): 72.92%
# --------------------------------------------------------------------------------
# Training... Epoch = 26
# Epoch 26, Batch 183/183 (41.3s): Center loss 0.5748, Softmax loss 0.4057, total 0.9822
# Train accuracy: 96.23%
# Validation mAP (split  5/5) (2.6s): 75.22%
# --------------------------------------------------------------------------------
# Training... Epoch = 27
# Epoch 27, Batch 183/183 (40.9s): Center loss 0.5713, Softmax loss 0.3918, total 0.9649
# Train accuracy: 96.45%
# Validation mAP (split  5/5) (2.5s): 74.76%
# --------------------------------------------------------------------------------
# Training... Epoch = 28
# Epoch 28, Batch 183/183 (40.9s): Center loss 0.5729, Softmax loss 0.3905, total 0.9652
# Train accuracy: 96.48%
# Validation mAP (split  5/5) (2.5s): 74.23%
# --------------------------------------------------------------------------------
# Training... Epoch = 29
# Epoch 29, Batch 183/183 (40.9s): Center loss 0.5645, Softmax loss 0.3752, total 0.9416
# Train accuracy: 96.90%
# Validation mAP (split  5/5) (2.6s): 75.82%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 75.41% | 75.82%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 30
# Epoch 30, Batch 183/183 (41.0s): Center loss 0.5687, Softmax loss 0.3743, total 0.9448
# Train accuracy: 96.93%
# Validation mAP (split  5/5) (3.1s): 75.57%
# --------------------------------------------------------------------------------
# Training... Epoch = 31
# Epoch 31, Batch 183/183 (43.0s): Center loss 0.5724, Softmax loss 0.3719, total 0.9462
# Train accuracy: 97.07%
# Validation mAP (split  5/5) (2.7s): 73.55%
# --------------------------------------------------------------------------------
# Training... Epoch = 32
# Epoch 32, Batch 183/183 (42.5s): Center loss 0.5656, Softmax loss 0.3621, total 0.9297
# Train accuracy: 97.03%
# Validation mAP (split  5/5) (2.9s): 74.55%
# --------------------------------------------------------------------------------
# Training... Epoch = 33
# Epoch 33, Batch 183/183 (42.8s): Center loss 0.5670, Softmax loss 0.3605, total 0.9295
# Train accuracy: 97.10%
# Validation mAP (split  5/5) (3.0s): 74.38%
# --------------------------------------------------------------------------------
# Training... Epoch = 34
# Epoch 34, Batch 183/183 (42.9s): Center loss 0.5659, Softmax loss 0.3602, total 0.9282
# Train accuracy: 97.01%
# Validation mAP (split  5/5) (3.9s): 74.09%
# --------------------------------------------------------------------------------
# Training... Epoch = 35
# Epoch 35, Batch 183/183 (43.0s): Center loss 0.5647, Softmax loss 0.3559, total 0.9228
# Train accuracy: 97.09%
# Validation mAP (split  5/5) (2.5s): 74.85%
# --------------------------------------------------------------------------------
# Training... Epoch = 36
# Epoch 36, Batch 183/183 (41.9s): Center loss 0.5627, Softmax loss 0.3501, total 0.9148
# Train accuracy: 97.22%
# Validation mAP (split  5/5) (3.5s): 77.33%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 75.82% | 77.33%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 37
# Epoch 37, Batch 183/183 (42.0s): Center loss 0.5635, Softmax loss 0.3472, total 0.9128
# Train accuracy: 97.30%
# Validation mAP (split  5/5) (2.6s): 75.16%
# --------------------------------------------------------------------------------
# Training... Epoch = 38
# Epoch 38, Batch 183/183 (41.1s): Center loss 0.5589, Softmax loss 0.3408, total 0.9018
# Train accuracy: 97.48%
# Validation mAP (split  5/5) (2.9s): 75.10%
# --------------------------------------------------------------------------------
# Training... Epoch = 39
# Epoch 39, Batch 183/183 (42.4s): Center loss 0.5601, Softmax loss 0.3416, total 0.9039
# Train accuracy: 97.22%
# Validation mAP (split  5/5) (2.9s): 76.09%
# --------------------------------------------------------------------------------
# Training... Epoch = 40
# Epoch 40, Batch 183/183 (41.8s): Center loss 0.5584, Softmax loss 0.3384, total 0.8990
# Train accuracy: 97.30%
# Validation mAP (split  5/5) (3.2s): 75.30%
# --------------------------------------------------------------------------------
# Training... Epoch = 41
# Epoch 41, Batch 183/183 (41.5s): Center loss 0.5549, Softmax loss 0.3318, total 0.8889
# Train accuracy: 97.51%
# Validation mAP (split  5/5) (3.6s): 75.43%
# --------------------------------------------------------------------------------
# Training... Epoch = 42
# Epoch 42, Batch 183/183 (42.7s): Center loss 0.5515, Softmax loss 0.3237, total 0.8775
# Train accuracy: 97.60%
# Validation mAP (split  5/5) (2.6s): 76.36%
# --------------------------------------------------------------------------------
# Training... Epoch = 43
# Epoch 43, Batch 183/183 (42.1s): Center loss 0.5535, Softmax loss 0.3245, total 0.8802
# Train accuracy: 97.66%
# Validation mAP (split  5/5) (3.1s): 76.90%
# --------------------------------------------------------------------------------
# Training... Epoch = 44
# Epoch 44, Batch 183/183 (42.7s): Center loss 0.5566, Softmax loss 0.3282, total 0.8870
# Train accuracy: 97.60%
# Validation mAP (split  5/5) (2.6s): 77.73%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 77.33% | 77.73%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 45
# Epoch 45, Batch 183/183 (41.9s): Center loss 0.5470, Softmax loss 0.3159, total 0.8652
# Train accuracy: 97.78%
# Validation mAP (split  5/5) (3.1s): 76.63%
# --------------------------------------------------------------------------------
# Training... Epoch = 46
# Epoch 46, Batch 183/183 (41.5s): Center loss 0.5487, Softmax loss 0.3176, total 0.8686
# Train accuracy: 97.65%
# Validation mAP (split  5/5) (2.6s): 73.87%
# --------------------------------------------------------------------------------
# Training... Epoch = 47
# Epoch 47, Batch 183/183 (41.1s): Center loss 0.5516, Softmax loss 0.3212, total 0.8751
# Train accuracy: 97.59%
# Validation mAP (split  5/5) (2.7s): 76.39%
# --------------------------------------------------------------------------------
# Training... Epoch = 48
# Epoch 48, Batch 183/183 (41.3s): Center loss 0.5451, Softmax loss 0.3107, total 0.8582
# Train accuracy: 97.94%
# Validation mAP (split  5/5) (2.7s): 76.04%
# --------------------------------------------------------------------------------
# Training... Epoch = 49
# Epoch 49, Batch 183/183 (41.4s): Center loss 0.5500, Softmax loss 0.3175, total 0.8697
# Train accuracy: 97.70%
# Validation mAP (split  5/5) (3.7s): 71.47%
# --------------------------------------------------------------------------------
# Training... Epoch = 50
# Epoch 50, Batch 183/183 (43.6s): Center loss 0.5455, Softmax loss 0.3091, total 0.8569
# Train accuracy: 97.81%
# Validation mAP (split  5/5) (3.1s): 75.86%
# --------------------------------------------------------------------------------
# Training... Epoch = 51
# Epoch 51, Batch 183/183 (42.7s): Center loss 0.5462, Softmax loss 0.3076, total 0.8561
# Train accuracy: 98.02%
# Validation mAP (split  5/5) (2.6s): 77.06%
# --------------------------------------------------------------------------------
# Training... Epoch = 52
# Epoch 52, Batch 183/183 (43.7s): Center loss 0.5431, Softmax loss 0.3065, total 0.8519
# Train accuracy: 97.92%
# Validation mAP (split  5/5) (3.0s): 76.71%
# --------------------------------------------------------------------------------
# Training... Epoch = 53
# Epoch 53, Batch 183/183 (43.6s): Center loss 0.5403, Softmax loss 0.3030, total 0.8457
# Train accuracy: 97.90%
# Validation mAP (split  5/5) (2.9s): 76.27%
# --------------------------------------------------------------------------------
# Training... Epoch = 54
# Epoch 54, Batch 183/183 (43.8s): Center loss 0.5430, Softmax loss 0.3048, total 0.8501
# Train accuracy: 97.88%
# Validation mAP (split  5/5) (3.0s): 77.13%
# --------------------------------------------------------------------------------
# Training... Epoch = 55
# Epoch 55, Batch 183/183 (44.2s): Center loss 0.5349, Softmax loss 0.2980, total 0.8353
# Train accuracy: 98.04%
# Validation mAP (split  5/5) (3.0s): 75.13%
# --------------------------------------------------------------------------------
# Training... Epoch = 56
# Epoch 56, Batch 183/183 (43.8s): Center loss 0.5394, Softmax loss 0.3050, total 0.8468
# Train accuracy: 97.72%
# Validation mAP (split  5/5) (2.9s): 76.04%
# --------------------------------------------------------------------------------
# Training... Epoch = 57
# Epoch 57, Batch 183/183 (43.8s): Center loss 0.5353, Softmax loss 0.2980, total 0.8357
# Train accuracy: 98.01%
# Validation mAP (split  5/5) (3.2s): 75.11%
# --------------------------------------------------------------------------------
# Training... Epoch = 58
# Epoch 58, Batch 183/183 (45.0s): Center loss 0.5386, Softmax loss 0.3012, total 0.8422
# Train accuracy: 97.98%
# Validation mAP (split  5/5) (3.0s): 77.75%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 77.73% | 77.75%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 59
# Epoch 59, Batch 183/183 (44.4s): Center loss 0.5343, Softmax loss 0.2968, total 0.8335
# Train accuracy: 98.00%
# Validation mAP (split  5/5) (3.3s): 78.29%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 77.75% | 78.29%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 60
# Epoch 60, Batch 183/183 (44.3s): Center loss 0.5349, Softmax loss 0.2931, total 0.8304
# Train accuracy: 98.17%
# Validation mAP (split  5/5) (3.2s): 75.82%
# --------------------------------------------------------------------------------
# Training... Epoch = 61
# Epoch 61, Batch 183/183 (44.0s): Center loss 0.5348, Softmax loss 0.2953, total 0.8324
# Train accuracy: 97.99%
# Validation mAP (split  5/5) (3.4s): 76.60%
# --------------------------------------------------------------------------------
# Training... Epoch = 62
# Epoch 62, Batch 183/183 (44.2s): Center loss 0.5401, Softmax loss 0.3018, total 0.8443
# Train accuracy: 97.93%
# Validation mAP (split  5/5) (3.0s): 77.12%
# --------------------------------------------------------------------------------
# Training... Epoch = 63
# Epoch 63, Batch 183/183 (43.9s): Center loss 0.5295, Softmax loss 0.2877, total 0.8196
# Train accuracy: 98.29%
# Validation mAP (split  5/5) (2.8s): 78.04%
# --------------------------------------------------------------------------------
# Training... Epoch = 64
# Epoch 64, Batch 183/183 (47.1s): Center loss 0.5293, Softmax loss 0.2889, total 0.8206
# Train accuracy: 98.06%
# Validation mAP (split  5/5) (5.2s): 77.54%
# --------------------------------------------------------------------------------
# Training... Epoch = 65
# Epoch 65, Batch 183/183 (45.0s): Center loss 0.5293, Softmax loss 0.2857, total 0.8174
# Train accuracy: 98.24%
# Validation mAP (split  5/5) (3.8s): 77.86%
# --------------------------------------------------------------------------------
# Training... Epoch = 66
# Epoch 66, Batch 183/183 (44.0s): Center loss 0.5315, Softmax loss 0.2911, total 0.8249
# Train accuracy: 98.06%
# Validation mAP (split  5/5) (3.3s): 75.89%
# --------------------------------------------------------------------------------
# Training... Epoch = 67
# Epoch 67, Batch 183/183 (43.5s): Center loss 0.5294, Softmax loss 0.2887, total 0.8205
# Train accuracy: 98.09%
# Validation mAP (split  5/5) (3.5s): 76.60%
# --------------------------------------------------------------------------------
# Training... Epoch = 68
# Epoch 68, Batch 183/183 (43.0s): Center loss 0.5287, Softmax loss 0.2857, total 0.8169
# Train accuracy: 98.21%
# Validation mAP (split  5/5) (2.6s): 76.95%
# --------------------------------------------------------------------------------
# Training... Epoch = 69
# Epoch 69, Batch 183/183 (42.6s): Center loss 0.5259, Softmax loss 0.2829, total 0.8112
# Train accuracy: 98.26%
# Validation mAP (split  5/5) (2.8s): 76.85%
# --------------------------------------------------------------------------------
# Training... Epoch = 70
# Epoch 70, Batch 183/183 (42.0s): Center loss 0.5274, Softmax loss 0.2855, total 0.8153
# Train accuracy: 98.21%
# Validation mAP (split  5/5) (2.6s): 77.79%
# --------------------------------------------------------------------------------
# Training... Epoch = 71
# Epoch 71, Batch 183/183 (44.3s): Center loss 0.5299, Softmax loss 0.2873, total 0.8196
# Train accuracy: 98.16%
# Validation mAP (split  5/5) (4.4s): 78.00%
# --------------------------------------------------------------------------------
# Training... Epoch = 72
# Epoch 72, Batch 183/183 (42.5s): Center loss 0.5208, Softmax loss 0.2791, total 0.8023
# Train accuracy: 98.32%
# Validation mAP (split  5/5) (2.9s): 77.61%
# --------------------------------------------------------------------------------
# Training... Epoch = 73
# Epoch 73, Batch 183/183 (42.5s): Center loss 0.5225, Softmax loss 0.2822, total 0.8072
# Train accuracy: 98.16%
# Validation mAP (split  5/5) (2.6s): 77.44%
# --------------------------------------------------------------------------------
# Training... Epoch = 74
# Epoch 74, Batch 183/183 (41.8s): Center loss 0.5213, Softmax loss 0.2789, total 0.8026
# Train accuracy: 98.35%
# Validation mAP (split  5/5) (2.6s): 77.94%
# --------------------------------------------------------------------------------
# Training... Epoch = 75
# Epoch 75, Batch 183/183 (41.2s): Center loss 0.5214, Softmax loss 0.2802, total 0.8041
# Train accuracy: 98.25%
# Validation mAP (split  5/5) (2.6s): 77.60%
# --------------------------------------------------------------------------------
# Training... Epoch = 76
# Epoch 76, Batch 183/183 (42.8s): Center loss 0.5190, Softmax loss 0.2738, total 0.7952
# Train accuracy: 98.50%
# Validation mAP (split  5/5) (2.7s): 77.59%
# --------------------------------------------------------------------------------
# Training... Epoch = 77
# Epoch 77, Batch 183/183 (41.9s): Center loss 0.5200, Softmax loss 0.2758, total 0.7982
# Train accuracy: 98.27%
# Validation mAP (split  5/5) (2.9s): 77.50%
# --------------------------------------------------------------------------------
# Training... Epoch = 78
# Epoch 78, Batch 183/183 (42.9s): Center loss 0.5201, Softmax loss 0.2772, total 0.7997
# Train accuracy: 98.21%
# Validation mAP (split  5/5) (2.8s): 76.16%
# --------------------------------------------------------------------------------
# Training... Epoch = 79
# Epoch 79, Batch 183/183 (42.4s): Center loss 0.5191, Softmax loss 0.2732, total 0.7947
# Train accuracy: 98.41%
# Validation mAP (split  5/5) (2.7s): 75.86%
# --------------------------------------------------------------------------------
# Training... Epoch = 80
# Epoch 80, Batch 183/183 (41.6s): Center loss 0.5172, Softmax loss 0.2733, total 0.7929
# Train accuracy: 98.35%
# Validation mAP (split  5/5) (3.2s): 78.46%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 78.29% | 78.46%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 81
# Epoch 81, Batch 183/183 (41.4s): Center loss 0.5200, Softmax loss 0.2774, total 0.7999
# Train accuracy: 98.19%
# Validation mAP (split  5/5) (5.2s): 77.83%
# --------------------------------------------------------------------------------
# Training... Epoch = 82
# Epoch 82, Batch 183/183 (41.8s): Center loss 0.5164, Softmax loss 0.2718, total 0.7907
# Train accuracy: 98.36%
# Validation mAP (split  5/5) (4.9s): 78.60%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 78.46% | 78.60%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 83
# Epoch 83, Batch 183/183 (41.6s): Center loss 0.5172, Softmax loss 0.2717, total 0.7914
# Train accuracy: 98.41%
# Validation mAP (split  5/5) (6.3s): 76.63%
# --------------------------------------------------------------------------------
# Training... Epoch = 84
# Epoch 84, Batch 183/183 (41.8s): Center loss 0.5171, Softmax loss 0.2709, total 0.7905
# Train accuracy: 98.34%
# Validation mAP (split  5/5) (7.5s): 79.33%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 78.60% | 79.33%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 85
# Epoch 85, Batch 183/183 (41.4s): Center loss 0.5123, Softmax loss 0.2679, total 0.7827
# Train accuracy: 98.42%
# Validation mAP (split  5/5) (6.8s): 78.14%
# --------------------------------------------------------------------------------
# Training... Epoch = 86
# Epoch 86, Batch 183/183 (41.1s): Center loss 0.5161, Softmax loss 0.2670, total 0.7855
# Train accuracy: 98.55%
# Validation mAP (split  5/5) (8.4s): 78.26%
# --------------------------------------------------------------------------------
# Training... Epoch = 87
# Epoch 87, Batch 183/183 (41.1s): Center loss 0.5171, Softmax loss 0.2695, total 0.7891
# Train accuracy: 98.54%
# Validation mAP (split  5/5) (8.6s): 75.65%
# --------------------------------------------------------------------------------
# Training... Epoch = 88
# Epoch 88, Batch 183/183 (41.0s): Center loss 0.5139, Softmax loss 0.2720, total 0.7883
# Train accuracy: 98.45%
# Validation mAP (split  5/5) (6.4s): 78.40%
# --------------------------------------------------------------------------------
# Training... Epoch = 89
# Epoch 89, Batch 183/183 (41.0s): Center loss 0.5120, Softmax loss 0.2673, total 0.7818
# Train accuracy: 98.42%
# Validation mAP (split  5/5) (6.5s): 77.11%
# --------------------------------------------------------------------------------
# Training... Epoch = 90
# Epoch 90, Batch 183/183 (41.0s): Center loss 0.5150, Softmax loss 0.2689, total 0.7863
# Train accuracy: 98.38%
# Validation mAP (split  5/5) (5.4s): 78.71%
# --------------------------------------------------------------------------------
# Training... Epoch = 91
# Epoch 91, Batch 183/183 (41.1s): Center loss 0.5081, Softmax loss 0.2624, total 0.7729
# Train accuracy: 98.60%
# Validation mAP (split  5/5) (5.6s): 76.98%
# --------------------------------------------------------------------------------
# Training... Epoch = 92
# Epoch 92, Batch 183/183 (41.1s): Center loss 0.5109, Softmax loss 0.2658, total 0.7791
# Train accuracy: 98.58%
# Validation mAP (split  5/5) (6.4s): 77.76%
# --------------------------------------------------------------------------------
# Training... Epoch = 93
# Epoch 93, Batch 183/183 (41.1s): Center loss 0.5098, Softmax loss 0.2639, total 0.7761
# Train accuracy: 98.50%
# Validation mAP (split  5/5) (6.2s): 78.28%
# --------------------------------------------------------------------------------
# Training... Epoch = 94
# Epoch 94, Batch 183/183 (41.1s): Center loss 0.5080, Softmax loss 0.2636, total 0.7740
# Train accuracy: 98.47%
# Validation mAP (split  5/5) (6.6s): 77.70%
# --------------------------------------------------------------------------------
# Training... Epoch = 95
# Epoch 95, Batch 183/183 (41.1s): Center loss 0.5120, Softmax loss 0.2674, total 0.7819
# Train accuracy: 98.41%
# Validation mAP (split  5/5) (6.0s): 77.58%
# --------------------------------------------------------------------------------
# Training... Epoch = 96
# Epoch 96, Batch 183/183 (41.0s): Center loss 0.5072, Softmax loss 0.2606, total 0.7702
# Train accuracy: 98.54%
# Validation mAP (split  5/5) (5.5s): 78.31%
# --------------------------------------------------------------------------------
# Training... Epoch = 97
# Epoch 97, Batch 183/183 (41.1s): Center loss 0.5126, Softmax loss 0.2680, total 0.7831
# Train accuracy: 98.32%
# Validation mAP (split  5/5) (5.1s): 77.20%
# --------------------------------------------------------------------------------
# Training... Epoch = 98
# Epoch 98, Batch 183/183 (41.1s): Center loss 0.5063, Softmax loss 0.2613, total 0.7701
# Train accuracy: 98.47%
# Validation mAP (split  5/5) (5.4s): 78.02%
# --------------------------------------------------------------------------------
# Training... Epoch = 99
# Epoch 99, Batch 183/183 (41.1s): Center loss 0.5091, Softmax loss 0.2656, total 0.7771
# Train accuracy: 98.53%
# Validation mAP (split  5/5) (5.8s): 77.85%
# --------------------------------------------------------------------------------
# Training... Epoch = 100
# Epoch 100, Batch 183/183 (41.1s): Center loss 0.5066, Softmax loss 0.2609, total 0.7700
# Train accuracy: 98.58%
# Validation mAP (split  5/5) (5.6s): 78.21%
# --------------------------------------------------------------------------------
# Training... Epoch = 101
# Epoch 101, Batch 183/183 (41.0s): Center loss 0.5041, Softmax loss 0.2584, total 0.7649
# Train accuracy: 98.54%
# Validation mAP (split  5/5) (5.8s): 77.94%
# --------------------------------------------------------------------------------
# Training... Epoch = 102
# Epoch 102, Batch 183/183 (41.1s): Center loss 0.5111, Softmax loss 0.2633, total 0.7769
# Train accuracy: 98.54%
# Validation mAP (split  5/5) (6.0s): 78.46%
# --------------------------------------------------------------------------------
# Training... Epoch = 103
# Epoch 103, Batch 183/183 (41.1s): Center loss 0.5053, Softmax loss 0.2617, total 0.7694
# Train accuracy: 98.49%
# Validation mAP (split  5/5) (6.3s): 78.45%
# --------------------------------------------------------------------------------
# Training... Epoch = 104
# Epoch 104, Batch 183/183 (41.1s): Center loss 0.5036, Softmax loss 0.2588, total 0.7649
# Train accuracy: 98.53%
# Validation mAP (split  5/5) (5.8s): 75.51%
# --------------------------------------------------------------------------------
# Training... Epoch = 105
# Epoch 105, Batch 183/183 (41.1s): Center loss 0.5061, Softmax loss 0.2600, total 0.7685
# Train accuracy: 98.64%
# Validation mAP (split  5/5) (5.3s): 76.32%
# --------------------------------------------------------------------------------
# Training... Epoch = 106
# Epoch 106, Batch 183/183 (41.1s): Center loss 0.5069, Softmax loss 0.2607, total 0.7701
# Train accuracy: 98.58%
# Validation mAP (split  5/5) (4.5s): 76.90%
# --------------------------------------------------------------------------------
# Training... Epoch = 107
# Epoch 107, Batch 183/183 (41.2s): Center loss 0.5038, Softmax loss 0.2563, total 0.7626
# Train accuracy: 98.65%
# Validation mAP (split  5/5) (4.7s): 79.02%
# --------------------------------------------------------------------------------
# Training... Epoch = 108
# Epoch 108, Batch 183/183 (41.2s): Center loss 0.5031, Softmax loss 0.2564, total 0.7620
# Train accuracy: 98.62%
# Validation mAP (split  5/5) (5.5s): 76.29%
# --------------------------------------------------------------------------------
# Training... Epoch = 109
# Epoch 109, Batch 183/183 (41.0s): Center loss 0.4992, Softmax loss 0.2532, total 0.7548
# Train accuracy: 98.74%
# Validation mAP (split  5/5) (5.0s): 77.85%
# --------------------------------------------------------------------------------
# Training... Epoch = 110
# Epoch 110, Batch 183/183 (41.1s): Center loss 0.5035, Softmax loss 0.2565, total 0.7624
# Train accuracy: 98.54%
# Validation mAP (split  5/5) (5.2s): 78.06%
# --------------------------------------------------------------------------------
# Training... Epoch = 111
# Epoch 111, Batch 183/183 (41.1s): Center loss 0.5029, Softmax loss 0.2596, total 0.7649
# Train accuracy: 98.38%
# Validation mAP (split  5/5) (5.6s): 75.94%
# --------------------------------------------------------------------------------
# Training... Epoch = 112
# Epoch 112, Batch 183/183 (41.1s): Center loss 0.4999, Softmax loss 0.2560, total 0.7584
# Train accuracy: 98.51%
# Validation mAP (split  5/5) (4.9s): 77.48%
# --------------------------------------------------------------------------------
# Training... Epoch = 113
# Epoch 113, Batch 183/183 (41.2s): Center loss 0.4970, Softmax loss 0.2512, total 0.7506
# Train accuracy: 98.77%
# Validation mAP (split  5/5) (7.2s): 77.00%
# --------------------------------------------------------------------------------
# Training... Epoch = 114
# Epoch 114, Batch 183/183 (41.0s): Center loss 0.5004, Softmax loss 0.2558, total 0.7587
# Train accuracy: 98.51%
# Validation mAP (split  5/5) (5.7s): 76.06%
# --------------------------------------------------------------------------------
# Training... Epoch = 115
# Epoch 115, Batch 183/183 (41.0s): Center loss 0.5011, Softmax loss 0.2554, total 0.7590
# Train accuracy: 98.59%
# Validation mAP (split  5/5) (5.5s): 75.79%
# --------------------------------------------------------------------------------
# Training... Epoch = 116
# Epoch 116, Batch 183/183 (40.9s): Center loss 0.5037, Softmax loss 0.2595, total 0.7657
# Train accuracy: 98.48%
# Validation mAP (split  5/5) (5.1s): 77.54%
# --------------------------------------------------------------------------------
# Training... Epoch = 117
# Epoch 117, Batch 183/183 (40.9s): Center loss 0.4991, Softmax loss 0.2530, total 0.7545
# Train accuracy: 98.65%
# Validation mAP (split  5/5) (4.7s): 77.05%
# --------------------------------------------------------------------------------
# Training... Epoch = 118
# Epoch 118, Batch 183/183 (41.0s): Center loss 0.4992, Softmax loss 0.2539, total 0.7555
# Train accuracy: 98.65%
# Validation mAP (split  5/5) (4.2s): 76.13%
# --------------------------------------------------------------------------------
# Training... Epoch = 119
# Epoch 119, Batch 183/183 (40.9s): Center loss 0.5014, Softmax loss 0.2533, total 0.7572
# Train accuracy: 98.73%
# Validation mAP (split  5/5) (3.8s): 76.58%
# --------------------------------------------------------------------------------
# Training... Epoch = 120
# Epoch 120, Batch 183/183 (41.0s): Center loss 0.4960, Softmax loss 0.2533, total 0.7518
# Train accuracy: 98.55%
# Validation mAP (split  5/5) (3.6s): 77.21%
# --------------------------------------------------------------------------------
# Training... Epoch = 121
# Epoch 121, Batch 183/183 (41.0s): Center loss 0.4993, Softmax loss 0.2536, total 0.7554
# Train accuracy: 98.51%
# Validation mAP (split  5/5) (3.8s): 77.77%
# --------------------------------------------------------------------------------
# Training... Epoch = 122
# Epoch 122, Batch 183/183 (41.1s): Center loss 0.4957, Softmax loss 0.2495, total 0.7477
# Train accuracy: 98.65%
# Validation mAP (split  5/5) (3.4s): 76.71%
# --------------------------------------------------------------------------------
# Training... Epoch = 123
# Epoch 123, Batch 183/183 (41.1s): Center loss 0.4974, Softmax loss 0.2527, total 0.7526
# Train accuracy: 98.68%
# Validation mAP (split  5/5) (4.1s): 76.59%
# --------------------------------------------------------------------------------
# Training... Epoch = 124
# Epoch 124, Batch 183/183 (41.0s): Center loss 0.4961, Softmax loss 0.2479, total 0.7465
# Train accuracy: 98.70%
# Validation mAP (split  5/5) (4.2s): 77.62%
# --------------------------------------------------------------------------------
# Training... Epoch = 125
# Epoch 125, Batch 183/183 (41.0s): Center loss 0.4942, Softmax loss 0.2496, total 0.7462
# Train accuracy: 98.61%
# Validation mAP (split  5/5) (3.8s): 74.73%
# --------------------------------------------------------------------------------
# Epoch   124: reducing learning rate of group 0 to 1.0000e-04.
# Training... Epoch = 126
# Epoch 126, Batch 183/183 (41.0s): Center loss 0.4210, Softmax loss 0.1638, total 0.5874
# Train accuracy: 99.61%
# Validation mAP (split  5/5) (3.5s): 80.64%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 79.33% | 80.64%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 127
# Epoch 127, Batch 183/183 (41.0s): Center loss 0.3797, Softmax loss 0.1384, total 0.5206
# Train accuracy: 99.81%
# Validation mAP (split  5/5) (4.0s): 81.18%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 80.64% | 81.18%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 128
# Epoch 128, Batch 183/183 (40.9s): Center loss 0.3690, Softmax loss 0.1327, total 0.5041
# Train accuracy: 99.88%
# Validation mAP (split  5/5) (3.1s): 81.29%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 81.18% | 81.29%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 129
# Epoch 129, Batch 183/183 (40.9s): Center loss 0.3630, Softmax loss 0.1304, total 0.4958
# Train accuracy: 99.92%
# Validation mAP (split  5/5) (3.6s): 81.37%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 81.29% | 81.37%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 130
# Epoch 130, Batch 183/183 (40.9s): Center loss 0.3569, Softmax loss 0.1295, total 0.4888
# Train accuracy: 99.88%
# Validation mAP (split  5/5) (4.4s): 81.58%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 81.37% | 81.58%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 131
# Epoch 131, Batch 183/183 (40.9s): Center loss 0.3532, Softmax loss 0.1273, total 0.4830
# Train accuracy: 99.93%
# Validation mAP (split  5/5) (4.4s): 81.83%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 81.58% | 81.83%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 132
# Epoch 132, Batch 183/183 (40.8s): Center loss 0.3526, Softmax loss 0.1273, total 0.4824
# Train accuracy: 99.90%
# Validation mAP (split  5/5) (4.7s): 81.96%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 81.83% | 81.96%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 133
# Epoch 133, Batch 183/183 (40.9s): Center loss 0.3535, Softmax loss 0.1269, total 0.4828
# Train accuracy: 99.91%
# Validation mAP (split  5/5) (4.4s): 81.62%
# --------------------------------------------------------------------------------
# Training... Epoch = 134
# Epoch 134, Batch 183/183 (40.9s): Center loss 0.3519, Softmax loss 0.1266, total 0.4809
# Train accuracy: 99.90%
# Validation mAP (split  5/5) (4.4s): 81.80%
# --------------------------------------------------------------------------------
# Training... Epoch = 135
# Epoch 135, Batch 183/183 (41.0s): Center loss 0.3523, Softmax loss 0.1258, total 0.4805
# Train accuracy: 99.92%
# Validation mAP (split  5/5) (4.2s): 82.09%
# --------------------------------------------------------------------------------
# Max. Valid. mAP / Epoch's Valid. mAP: 81.96% | 82.09%
# Salvando melhor modelo...
# --------------------------------------------------------------------------------
# Training... Epoch = 136
# Epoch 136, Batch 183/183 (40.9s): Center loss 0.3502, Softmax loss 0.1245, total 0.4772
# Train accuracy: 99.94%
# Validation mAP (split  5/5) (4.6s): 81.79%
# --------------------------------------------------------------------------------
# Training... Epoch = 137
# Epoch 137, Batch 183/183 (41.0s): Center loss 0.3510, Softmax loss 0.1241, total 0.4776
# Train accuracy: 99.93%
# Validation mAP (split  5/5) (4.4s): 81.74%
# --------------------------------------------------------------------------------
# Training... Epoch = 138
# Epoch 138, Batch 183/183 (40.9s): Center loss 0.3520, Softmax loss 0.1247, total 0.4792
# Train accuracy: 99.95%
# Validation mAP (split  5/5) (4.0s): 81.75%
# --------------------------------------------------------------------------------
# Training... Epoch = 139
# Epoch 139, Batch 183/183 (40.9s): Center loss 0.3510, Softmax loss 0.1238, total 0.4773
# Train accuracy: 99.94%
# Validation mAP (split  5/5) (3.9s): 81.57%
# --------------------------------------------------------------------------------
# Training... Epoch = 140
# Epoch 140, Batch 183/183 (41.0s): Center loss 0.3500, Softmax loss 0.1229, total 0.4753
# Train accuracy: 99.95%
# Validation mAP (split  5/5) (4.4s): 81.79%
# --------------------------------------------------------------------------------
# Training... Epoch = 141
# Epoch 141, Batch 183/183 (41.0s): Center loss 0.3510, Softmax loss 0.1235, total 0.4769
# Train accuracy: 99.94%
# Validation mAP (split  5/5) (3.7s): 81.63%
# --------------------------------------------------------------------------------
# Training... Epoch = 142
# Epoch 142, Batch 183/183 (40.8s): Center loss 0.3531, Softmax loss 0.1228, total 0.4783
# Train accuracy: 99.94%
# Validation mAP (split  5/5) (4.2s): 81.82%
# --------------------------------------------------------------------------------
# Training... Epoch = 143
# Epoch 143, Batch 183/183 (40.8s): Center loss 0.3518, Softmax loss 0.1231, total 0.4774
# Train accuracy: 99.94%
# Validation mAP (split  5/5) (4.2s): 81.58%
# --------------------------------------------------------------------------------
# Training... Epoch = 144
# Epoch 144, Batch 183/183 (40.9s): Center loss 0.3523, Softmax loss 0.1221, total 0.4769
# Train accuracy: 99.95%
# Validation mAP (split  5/5) (4.6s): 81.63%
# --------------------------------------------------------------------------------
# Training... Epoch = 145
# Epoch 145, Batch 183/183 (40.9s): Center loss 0.3512, Softmax loss 0.1215, total 0.4751
# Train accuracy: 99.97%
# Validation mAP (split  5/5) (4.6s): 81.41%
# --------------------------------------------------------------------------------
# Training... Epoch = 146
# Epoch 146, Batch 183/183 (41.0s): Center loss 0.3520, Softmax loss 0.1217, total 0.4762
# Train accuracy: 99.96%
# Validation mAP (split  5/5) (4.6s): 81.59%
# --------------------------------------------------------------------------------
# Training... Epoch = 147
# Epoch 147, Batch 183/183 (40.8s): Center loss 0.3515, Softmax loss 0.1201, total 0.4741
# Train accuracy: 99.95%
# Validation mAP (split  5/5) (4.6s): 81.84%
# --------------------------------------------------------------------------------
# Training... Epoch = 148
# Epoch 148, Batch 183/183 (40.8s): Center loss 0.3486, Softmax loss 0.1204, total 0.4714
# Train accuracy: 99.94%
# Validation mAP (split  5/5) (4.0s): 81.72%
# --------------------------------------------------------------------------------
# Training... Epoch = 149
# Epoch 149, Batch 183/183 (40.9s): Center loss 0.3503, Softmax loss 0.1198, total 0.4725
# Train accuracy: 99.94%
# Validation mAP (split  5/5) (3.7s): 81.54%
# --------------------------------------------------------------------------------
# Training... Epoch = 150
# Epoch 150, Batch 183/183 (40.8s): Center loss 0.3488, Softmax loss 0.1197, total 0.4710
# Train accuracy: 99.94%
# Validation mAP (split  5/5) (4.0s): 81.69%
# --------------------------------------------------------------------------------
# Training... Epoch = 151
# Epoch 151, Batch 183/183 (40.9s): Center loss 0.3498, Softmax loss 0.1204, total 0.4726
# Train accuracy: 99.96%
# Validation mAP (split  5/5) (4.4s): 81.49%
# --------------------------------------------------------------------------------
# Training... Epoch = 152
# Epoch 152, Batch 183/183 (40.9s): Center loss 0.3535, Softmax loss 0.1204, total 0.4763
# Train accuracy: 99.95%
# Validation mAP (split  5/5) (4.0s): 81.62%
# --------------------------------------------------------------------------------
# Training... Epoch = 153
# Epoch 153, Batch 183/183 (40.8s): Center loss 0.3524, Softmax loss 0.1202, total 0.4750
# Train accuracy: 99.95%
# Validation mAP (split  5/5) (4.2s): 81.49%
# --------------------------------------------------------------------------------
# Training... Epoch = 154
# Epoch 154, Batch 183/183 (40.8s): Center loss 0.3512, Softmax loss 0.1200, total 0.4737
# Train accuracy: 99.96%
# Validation mAP (split  5/5) (4.4s): 81.49%
# --------------------------------------------------------------------------------
# Training... Epoch = 155
# Epoch 155, Batch 183/183 (40.7s): Center loss 0.3534, Softmax loss 0.1203, total 0.4762
# Train accuracy: 99.93%
# Validation mAP (split  5/5) (4.2s): 81.60%
# --------------------------------------------------------------------------------
# Training... Epoch = 156
# Epoch 156, Batch 183/183 (40.8s): Center loss 0.3519, Softmax loss 0.1192, total 0.4736
# Train accuracy: 99.94%
# Validation mAP (split  5/5) (4.6s): 81.63%
# --------------------------------------------------------------------------------
# Training... Epoch = 157
# Epoch 157, Batch 183/183 (40.8s): Center loss 0.3506, Softmax loss 0.1187, total 0.4718
# Train accuracy: 99.95%
# Validation mAP (split  5/5) (4.4s): 81.51%
# --------------------------------------------------------------------------------
# Training... Epoch = 158
# Epoch 158, Batch 183/183 (40.8s): Center loss 0.3503, Softmax loss 0.1174, total 0.4702
# Train accuracy: 99.95%
# Validation mAP (split  5/5) (4.0s): 81.77%
# --------------------------------------------------------------------------------
# Training... Epoch = 159
# Epoch 159, Batch 183/183 (40.8s): Center loss 0.3528, Softmax loss 0.1186, total 0.4739
# Train accuracy: 99.95%
# Validation mAP (split  5/5) (3.3s): 81.25%
# --------------------------------------------------------------------------------
# Training... Epoch = 160
# Epoch 160, Batch 183/183 (40.8s): Center loss 0.3508, Softmax loss 0.1179, total 0.4712
# Train accuracy: 99.96%
# Validation mAP (split  5/5) (3.4s): 81.23%
# --------------------------------------------------------------------------------
# Training... Epoch = 161
# Epoch 161, Batch 183/183 (40.9s): Center loss 0.3524, Softmax loss 0.1185, total 0.4734
# Train accuracy: 99.96%
# Validation mAP (split  5/5) (3.3s): 81.05%
# --------------------------------------------------------------------------------
# Training... Epoch = 162
# Epoch 162, Batch 183/183 (40.8s): Center loss 0.3510, Softmax loss 0.1175, total 0.4711
# Train accuracy: 99.94%
# Validation mAP (split  5/5) (3.3s): 81.27%
# --------------------------------------------------------------------------------
# Training... Epoch = 163
# Epoch 163, Batch 183/183 (40.8s): Center loss 0.3509, Softmax loss 0.1178, total 0.4712
# Train accuracy: 99.94%
# Validation mAP (split  5/5) (3.8s): 80.93%
# --------------------------------------------------------------------------------
# Training... Epoch = 164
# Epoch 164, Batch 183/183 (40.8s): Center loss 0.3540, Softmax loss 0.1184, total 0.4749
# Train accuracy: 99.96%
# Validation mAP (split  5/5) (3.7s): 80.85%
# --------------------------------------------------------------------------------
# Training... Epoch = 165
# Epoch 165, Batch 183/183 (40.7s): Center loss 0.3510, Softmax loss 0.1168, total 0.4703
# Train accuracy: 99.94%
# Validation mAP (split  5/5) (3.7s): 81.06%
# --------------------------------------------------------------------------------
# Training... Epoch = 166
# Epoch 166, Batch 183/183 (40.9s): Center loss 0.3477, Softmax loss 0.1159, total 0.4660
# Train accuracy: 99.96%
# Validation mAP (split  5/5) (4.2s): 80.98%
# --------------------------------------------------------------------------------
# Training... Epoch = 167
# Epoch 167, Batch 183/183 (40.7s): Center loss 0.3513, Softmax loss 0.1174, total 0.4711
# Train accuracy: 99.95%
# Validation mAP (split  5/5) (3.6s): 81.03%
# --------------------------------------------------------------------------------
# Training... Epoch = 168
# Epoch 168, Batch 183/183 (40.8s): Center loss 0.3531, Softmax loss 0.1167, total 0.4723
# Train accuracy: 99.96%
# Validation mAP (split  5/5) (3.6s): 81.17%
# --------------------------------------------------------------------------------
# Training... Epoch = 169
# Epoch 169, Batch 183/183 (40.7s): Center loss 0.3501, Softmax loss 0.1161, total 0.4687
# Train accuracy: 99.96%
# Validation mAP (split  5/5) (3.9s): 80.77%
# --------------------------------------------------------------------------------
# Training... Epoch = 170
# Epoch 170, Batch 183/183 (40.7s): Center loss 0.3525, Softmax loss 0.1168, total 0.4718
# Train accuracy: 99.96%
# Validation mAP (split  5/5) (4.2s): 80.64%
# --------------------------------------------------------------------------------
# Training... Epoch = 171
# Epoch 171, Batch 183/183 (40.8s): Center loss 0.3500, Softmax loss 0.1163, total 0.4687
# Train accuracy: 99.94%
# Validation mAP (split  5/5) (4.2s): 80.69%
# --------------------------------------------------------------------------------
# Training... Epoch = 172
# Epoch 172, Batch 183/183 (40.7s): Center loss 0.3493, Softmax loss 0.1158, total 0.4676
# Train accuracy: 99.95%
# Validation mAP (split  5/5) (4.6s): 80.73%
# --------------------------------------------------------------------------------
# Training... Epoch = 173
# Epoch 173, Batch 183/183 (40.7s): Center loss 0.3528, Softmax loss 0.1174, total 0.4726
# Train accuracy: 99.94%
# Validation mAP (split  5/5) (4.6s): 80.72%
# --------------------------------------------------------------------------------
# Training... Epoch = 174
# Epoch 174, Batch 183/183 (40.7s): Center loss 0.3510, Softmax loss 0.1152, total 0.4687
# Train accuracy: 99.97%
# Validation mAP (split  5/5) (4.2s): 80.63%
# --------------------------------------------------------------------------------
# Training... Epoch = 175
# Epoch 175, Batch 183/183 (40.8s): Center loss 0.3498, Softmax loss 0.1155, total 0.4678
# Train accuracy: 99.94%
# Validation mAP (split  5/5) (4.2s): 81.12%
# --------------------------------------------------------------------------------
# Training... Epoch = 176
# Epoch 176, Batch 183/183 (41.2s): Center loss 0.3516, Softmax loss 0.1165, total 0.4706
# Train accuracy: 99.96%
# Validation mAP (split  5/5) (4.6s): 80.80%
# --------------------------------------------------------------------------------
# Epoch   175: reducing learning rate of group 0 to 1.0000e-05.
# Training... Epoch = 177
# Epoch 177, Batch 183/183 (41.1s): Center loss 0.3363, Softmax loss 0.1057, total 0.4445
# Train accuracy: 99.97%
# Validation mAP (split  5/5) (5.1s): 80.74%
# --------------------------------------------------------------------------------
# Training... Epoch = 178
# Epoch 178, Batch 183/183 (41.2s): Center loss 0.3310, Softmax loss 0.1034, total 0.4368
# Train accuracy: 99.98%
# Validation mAP (split  5/5) (4.6s): 80.90%
# --------------------------------------------------------------------------------
# Training... Epoch = 179
# Epoch 179, Batch 183/183 (41.2s): Center loss 0.3307, Softmax loss 0.1034, total 0.4366
# Train accuracy: 99.97%
# Validation mAP (split  5/5) (4.4s): 80.91%
# --------------------------------------------------------------------------------
# Training... Epoch = 180
# Epoch 180, Batch 183/183 (41.2s): Center loss 0.3291, Softmax loss 0.1027, total 0.4343
# Train accuracy: 99.97%
# Validation mAP (split  5/5) (4.6s): 80.85%
# --------------------------------------------------------------------------------
# Training... Epoch = 181
# Epoch 181, Batch 183/183 (41.3s): Center loss 0.3298, Softmax loss 0.1037, total 0.4360
# Train accuracy: 99.97%
# Validation mAP (split  5/5) (4.2s): 80.93%
# --------------------------------------------------------------------------------
# Training... Epoch = 182
# Epoch 182, Batch 183/183 (41.4s): Center loss 0.3247, Softmax loss 0.1019, total 0.4291
# Train accuracy: 99.97%
# Validation mAP (split  5/5) (4.6s): 81.01%
# --------------------------------------------------------------------------------
# Training... Epoch = 183
# Epoch 183, Batch 183/183 (41.3s): Center loss 0.3282, Softmax loss 0.1032, total 0.4338
# Train accuracy: 99.98%
# Validation mAP (split  5/5) (4.8s): 80.98%
# --------------------------------------------------------------------------------
# Training... Epoch = 184
# Epoch 184, Batch 183/183 (41.4s): Center loss 0.3257, Softmax loss 0.1020, total 0.4302
# Train accuracy: 99.98%
# Validation mAP (split  5/5) (4.7s): 80.91%
# --------------------------------------------------------------------------------
# Training... Epoch = 185
# Epoch 185, Batch 183/183 (41.5s): Center loss 0.3254, Softmax loss 0.1025, total 0.4304
# Train accuracy: 99.98%
# Validation mAP (split  5/5) (4.5s): 81.04%
# --------------------------------------------------------------------------------
# Training... Epoch = 186
# Epoch 186, Batch 183/183 (41.3s): Center loss 0.3271, Softmax loss 0.1027, total 0.4323
# Train accuracy: 99.98%
# Validation mAP (split  5/5) (4.6s): 80.94%
# --------------------------------------------------------------------------------
# Training... Epoch = 187
# Epoch 187, Batch 183/183 (41.3s): Center loss 0.3243, Softmax loss 0.1023, total 0.4291
# Train accuracy: 99.98%
# Validation mAP (split  5/5) (5.2s): 80.98%
# --------------------------------------------------------------------------------
# Training... Epoch = 188
# Epoch 188, Batch 183/183 (41.4s): Center loss 0.3246, Softmax loss 0.1017, total 0.4288
# Train accuracy: 99.98%
# Validation mAP (split  5/5) (5.2s): 81.05%
# --------------------------------------------------------------------------------
# Training... Epoch = 189
# Epoch 189, Batch 183/183 (41.3s): Center loss 0.3249, Softmax loss 0.1022, total 0.4296
# Train accuracy: 99.97%
# Validation mAP (split  5/5) (5.1s): 80.94%
# --------------------------------------------------------------------------------
# Training... Epoch = 190
# Epoch 190, Batch 183/183 (41.5s): Center loss 0.3261, Softmax loss 0.1028, total 0.4314
# Train accuracy: 99.98%
# Validation mAP (split  5/5) (5.0s): 81.05%
# --------------------------------------------------------------------------------
# Training... Epoch = 191
# Epoch 191, Batch 183/183 (41.3s): Center loss 0.3220, Softmax loss 0.1018, total 0.4263
# Train accuracy: 99.97%
# Validation mAP (split  5/5) (4.8s): 81.11%
# --------------------------------------------------------------------------------
# Early stopping at epoch 191.
